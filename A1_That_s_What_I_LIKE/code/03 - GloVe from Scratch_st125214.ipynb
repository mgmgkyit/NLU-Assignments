# %% [markdown]
# # GloVE
#
# Let's work on implementation of GloVE.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

print(torch.cuda.is_available()) # True if GPU is available
print(torch.cuda.device_count()) # Number of GPUs available
print(torch.cuda.current_device()) # Device index

device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # Select device
print(device)
# Out:
# True
# 1
# 0
# cuda

# %%
import nltk # natural language toolkit
from nltk.corpus import reuters # Reuters dataset
nltk.__version__
# Out:
# '3.9.1'

# %%
nltk.download('punkt') # download the punkt tokenizer
nltk.download('reuters') # download the reuters dataset
categiries = reuters.categories() # get the list of categories
print(categiries[:10])  # print the first 10 categories
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mgmgk\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package reuters to
# [nltk_data]     C:\Users\mgmgk\AppData\Roaming\nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# ['acq', 'alum', 'barley', 'bop', 'carcass', 'castor-oil', 'cocoa', 'coconut', 'coconut-oil', 'coffee']

# %% [markdown]
# ## 1. Load data

# %%
corpus = reuters.sents(categories='coffee') # get the list of sentences in the coffee category
# corpus = reuters.sents()  # Alternate way to get all the categories from reuters dataset
                            # When I tried this, it causes memory overflow and the kernel crashes,
                            # so I will stick to the coffee category for now for testing
corpus
# Out:
# [['INDONESIAN', 'COMMODITY', 'EXCHANGE', 'MAY', 'EXPAND', 'The', 'Indonesian', 'Commodity', 'Exchange', 'is', 'likely', 'to', 'start', 'trading', 'in', 'at', 'least', 'one', 'new', 'commodity', ',', 'and', 'possibly', 'two', ',', 'during', 'calendar', '1987', ',', 'exchange', 'chairman', 'Paian', 'Nainggolan', 'said', '.'], ['He', 'told', 'Reuters', 'in', 'a', 'telephone', 'interview', 'that', 'trading', 'in', 'palm', 'oil', ',', 'sawn', 'timber', ',', 'pepper', 'or', 'tobacco', 'was', 'being', 'considered', '.'], ...]

# %%
#2. numeralization
#find unique words
flatten = lambda l: [item for sublist in l for item in sublist]
#assign unique integer
vocabs = list(set(flatten(corpus))) #all the words we have in the system - <UNK>

# %%
#create handy mapping between integer and word to create word2index
word2index = {v:idx for idx, v in enumerate(vocabs)}
word2index['beans']
# Out:
# 2928

# %%
# adding 'UNK' to handle unknown word tokens
last_vocab_idx = len(vocabs)
last_vocab_idx
vocabs.append('<UNK>')
word2index['<UNK>'] = last_vocab_idx

# %%
# reverse mapping from word2index to index2word
index2word = {v:k for k, v in word2index.items()}
index2word[5]
# Out:
# 'AGO'

# %% [markdown]
# ## 2. Build Co-occurence Matrix X

# %% [markdown]
# Here, we need to count the co-occurence of two words given some window size.  We gonna use window size of 1.

# %%
from collections import Counter

X_i = Counter(flatten(corpus))
X_i
# Out:
# Counter({',': 1637,
#          '.': 1618,
#          'the': 1462,
#          'to': 968,
#          'of': 819,
#          'in': 609,
#          'and': 585,
#          'said': 576,
#          'a': 546,
#          'coffee': 375,
#          'for': 320,
#          "'": 284,
#          'on': 272,
#          '"': 271,
#          'The': 237,
#          's': 231,
#          '-': 206,
#          'is': 205,
#          'export': 197,
#          'be': 188,
#          'quotas': 187,
#          'will': 183,
#          'that': 182,
#          'ICO': 181,
#          'Coffee': 168,
#          'Brazil': 168,
#          'by': 160,
#          'not': 158,
#          'mln': 158,
#          'from': 157,
#          'at': 152,
#          '(': 149,
#          'with': 146,
#          'year': 145,
#          'would': 141,
#          'as': 132,
#          'prices': 130,
#          'have': 126,
#          'this': 125,
#          'was': 124,
#          ',"': 123,
#          'are': 120,
#          'market': 120,
#          ')': 119,
#          'an': 116,
#          'producers': 116,
#          'bags': 116,
#          'which': 114,
#          'its': 111,
#          'has': 108,
#          'it': 107,
#          'U': 107,
#          'S': 107,
#          'meeting': 107,
#          'he': 106,
#          '1': 104,
#          'quota': 103,
#          'COFFEE': 100,
#          'last': 100,
#          'were': 95,
#          'but': 90,
#          '000': 90,
#          'pct': 88,
#          'International': 86,
#          'they': 86,
#          'trade': 82,
#          'Colombia': 81,
#          'new': 78,
#          '1986': 77,
#          'exports': 77,
#          'countries': 77,
#          'talks': 76,
#          'been': 74,
#          'producer': 73,
#          'tonnes': 71,
#          'could': 71,
#          'dlrs': 70,
#          '/': 67,
#          'one': 64,
#          'had': 63,
#          'more': 62,
#          'week': 61,
#          'IBC': 61,
#          'He': 59,
#          'London': 59,
#          'told': 58,
#          'no': 58,
#          'sources': 58,
#          'delegates': 57,
#          'agreement': 54,
#          'world': 53,
#          'about': 53,
#          '5': 52,
#          'price': 52,
#          'two': 51,
#          'board': 51,
#          'added': 50,
#          'Organization': 49,
#          'up': 47,
#          'foreign': 47,
#          'government': 46,
#          'production': 45,
#          'crop': 45,
#          'consumers': 45,
#          '1987': 44,
#          'exporters': 44,
#          'Dauster': 44,
#          'than': 43,
#          'when': 42,
#          'their': 42,
#          'Brazilian': 42,
#          'there': 41,
#          'because': 41,
#          '1985': 40,
#          'A': 40,
#          'registrations': 40,
#          'today': 40,
#          '2': 40,
#          'also': 39,
#          'some': 39,
#          'if': 39,
#          'March': 39,
#          'September': 39,
#          'any': 39,
#          'billion': 38,
#          'month': 38,
#          'other': 38,
#          'country': 38,
#          'exchange': 37,
#          'official': 37,
#          'set': 37,
#          'or': 36,
#          'we': 36,
#          'April': 36,
#          'now': 36,
#          'TO': 36,
#          'over': 36,
#          '30': 34,
#          'negotiations': 34,
#          'New': 33,
#          '0': 33,
#          'Reuters': 32,
#          '."': 32,
#          'after': 32,
#          'while': 32,
#          'only': 32,
#          'cents': 32,
#          'May': 32,
#          'current': 32,
#          'expected': 32,
#          'group': 32,
#          'system': 31,
#          'Indonesia': 31,
#          'between': 31,
#          'Institute': 31,
#          'executive': 31,
#          'fall': 31,
#          'report': 30,
#          'policy': 30,
#          'NIL': 30,
#          'consumer': 30,
#          'February': 30,
#          '10': 30,
#          'But': 29,
#          'major': 29,
#          'president': 29,
#          '50': 29,
#          'members': 29,
#          '6': 28,
#          '87': 28,
#          'failure': 28,
#          'officials': 27,
#          'should': 27,
#          'end': 27,
#          '3': 27,
#          'total': 27,
#          '60': 27,
#          'recent': 27,
#          'around': 27,
#          'most': 27,
#          'under': 27,
#          'council': 27,
#          'down': 27,
#          'before': 27,
#          'during': 26,
#          'oil': 26,
#          'months': 26,
#          'next': 26,
#          'It': 26,
#          'India': 26,
#          're': 26,
#          'agree': 26,
#          'share': 26,
#          'stocks': 26,
#          'debt': 26,
#          'likely': 25,
#          'trading': 25,
#          'commodity': 25,
#          'first': 25,
#          'can': 25,
#          '4': 25,
#          'time': 25,
#          'position': 25,
#          'economic': 25,
#          'still': 24,
#          'per': 24,
#          'compared': 24,
#          'ended': 24,
#          'producing': 24,
#          'make': 23,
#          'since': 23,
#          'estimated': 23,
#          'such': 23,
#          'Kenya': 23,
#          'limit': 23,
#          'cocoa': 23,
#          'here': 23,
#          'failed': 23,
#          'In': 23,
#          'non': 22,
#          'York': 22,
#          'lower': 22,
#          'need': 22,
#          'how': 22,
#          'nations': 22,
#          'formula': 22,
#          'However': 22,
#          'marketing': 21,
#          'American': 21,
#          'private': 21,
#          'lb': 21,
#          'Organisation': 21,
#          'against': 21,
#          'future': 21,
#          'criteria': 21,
#          'early': 21,
#          'situation': 21,
#          'We': 20,
#          'do': 20,
#          'five': 20,
#          'traders': 20,
#          'largest': 20,
#          'forecast': 20,
#          'drop': 20,
#          '15': 20,
#          'Uganda': 20,
#          'without': 20,
#          'demand': 20,
#          'meet': 20,
#          'previous': 20,
#          'output': 20,
#          'due': 20,
#          'stock': 20,
#          'This': 20,
#          'may': 19,
#          'futures': 19,
#          'markets': 19,
#          'international': 19,
#          'banks': 19,
#          'session': 19,
#          'based': 19,
#          '),': 19,
#          'proposal': 19,
#          'spokesman': 19,
#          'who': 19,
#          'member': 19,
#          'following': 19,
#          'earlier': 19,
#          'sales': 19,
#          'high': 19,
#          'calendar': 18,
#          'until': 18,
#          '9': 18,
#          'COLOMBIA': 18,
#          'Arango': 18,
#          'Costa': 18,
#          'out': 18,
#          'objective': 18,
#          'analysts': 18,
#          'local': 18,
#          'state': 18,
#          'rise': 18,
#          'Exchange': 17,
#          'start': 17,
#          'Trade': 17,
#          'Minister': 17,
#          'support': 17,
#          'closed': 17,
#          'IN': 17,
#          'all': 17,
#          'dlr': 17,
#          'suspended': 17,
#          'long': 17,
#          'earnings': 17,
#          'including': 17,
#          'Rica': 17,
#          'continue': 17,
#          'his': 17,
#          'into': 17,
#          'much': 17,
#          'did': 17,
#          '86': 17,
#          'Jorio': 17,
#          'economy': 17,
#          'minister': 17,
#          'eight': 17,
#          'TALKS': 17,
#          'least': 16,
#          'so': 16,
#          'Cardenas': 16,
#          'June': 16,
#          'Colombian': 16,
#          'used': 16,
#          'shares': 16,
#          'among': 16,
#          'problems': 16,
#          'present': 16,
#          'six': 16,
#          'higher': 16,
#          'Gaviria': 16,
#          'African': 16,
#          '00': 16,
#          'pressure': 16,
#          'chairman': 15,
#          'made': 15,
#          'rubber': 15,
#          'National': 15,
#          'years': 15,
#          'same': 15,
#          '25': 15,
#          'period': 15,
#          'They': 15,
#          'farmers': 15,
#          'annual': 15,
#          'main': 15,
#          'roasters': 15,
#          'Bank': 15,
#          'delegate': 15,
#          'difficult': 15,
#          'analyst': 15,
#          'agreements': 15,
#          'sell': 15,
#          'open': 14,
#          'Latin': 14,
#          'close': 14,
#          'registered': 14,
#          'far': 14,
#          'average': 14,
#          '35': 14,
#          '7': 14,
#          'President': 14,
#          '--': 14,
#          'increase': 14,
#          'compromise': 14,
#          'drought': 14,
#          'does': 14,
#          'EXPORT': 14,
#          'tea': 14,
#          'term': 14,
#          'payments': 14,
#          'commodities': 14,
#          'NA': 14,
#          'low': 14,
#          'January': 13,
#          'second': 13,
#          'already': 13,
#          'use': 13,
#          'Mexico': 13,
#          'October': 13,
#          'them': 13,
#          'opened': 13,
#          'sold': 13,
#          'Board': 13,
#          'CMB': 13,
#          'three': 13,
#          'green': 13,
#          'day': 13,
#          'many': 13,
#          'distribution': 13,
#          'basis': 13,
#          'Agreement': 13,
#          'return': 13,
#          'reflect': 13,
#          'Ivory': 13,
#          'Coast': 13,
#          'below': 13,
#          'United': 13,
#          'imports': 13,
#          'take': 13,
#          'buying': 13,
#          'further': 13,
#          '&': 13,
#          ';': 13,
#          'political': 13,
#          'fell': 13,
#          '11': 13,
#          'increased': 13,
#          'Ltd': 13,
#          'go': 12,
#          'move': 12,
#          'No': 12,
#          'help': 12,
#          'change': 12,
#          'SAO': 12,
#          'show': 12,
#          'Kenyan': 12,
#          'ending': 12,
#          'kilo': 12,
#          'each': 12,
#          'NO': 12,
#          'pay': 12,
#          'agreed': 12,
#          'If': 12,
#          'supply': 12,
#          'At': 12,
#          'just': 12,
#          'There': 12,
#          'reach': 12,
#          't': 12,
#          'see': 12,
#          'I': 12,
#          'lt': 12,
#          'reporters': 12,
#          'discuss': 12,
#          'according': 12,
#          'countertrade': 12,
#          'even': 12,
#          'way': 12,
#          'Central': 12,
#          'proposed': 12,
#          'exported': 12,
#          'Indonesian': 11,
#          'being': 11,
#          'four': 11,
#          'factors': 11,
#          'Robusta': 11,
#          'introduction': 11,
#          'although': 11,
#          'Department': 11,
#          'another': 11,
#          'plans': 11,
#          'amount': 11,
#          '13': 11,
#          'THE': 11,
#          'STATE': 11,
#          'figures': 11,
#          '8': 11,
#          '100': 11,
#          'Guatemala': 11,
#          'past': 11,
#          'statement': 11,
#          'give': 11,
#          'Association': 11,
#          'our': 11,
#          'full': 11,
#          'Nicaragua': 11,
#          'plan': 11,
#          'harvest': 11,
#          'season': 11,
#          'Agriculture': 11,
#          'bag': 11,
#          'goods': 11,
#          'flexible': 11,
#          'Cocoa': 11,
#          'special': 11,
#          'unlikely': 11,
#          'decline': 11,
#          'exporter': 11,
#          'cut': 11,
#          'Managua': 11,
#          'stg': 11,
#          'continued': 11,
#          'broke': 11,
#          'consuming': 11,
#          'work': 11,
#          'like': 11,
#          'case': 11,
#          'sugar': 11,
#          'contact': 11,
#          'revenue': 11,
#          'Cherry': 11,
#          'MM': 11,
#          'breakdown': 11,
#          'currently': 10,
#          'days': 10,
#          'contracts': 10,
#          'say': 10,
#          'good': 10,
#          'account': 10,
#          'third': 10,
#          'Growers': 10,
#          'Federation': 10,
#          'shipment': 10,
#          ':': 10,
#          '18': 10,
#          'FOR': 10,
#          'rose': 10,
#          'surplus': 10,
#          'finance': 10,
#          'large': 10,
#          'Peru': 10,
#          'real': 10,
#          'include': 10,
#          'de': 10,
#          'positions': 10,
#          '16': 10,
#          'QUOTA': 10,
#          'little': 10,
#          'despite': 10,
#          'Rosenbaum': 10,
#          'reintroduction': 10,
#          '88': 10,
#          'record': 10,
#          'States': 10,
#          'source': 10,
#          'selling': 10,
#          '12': 10,
#          'contribution': 10,
#          'opening': 10,
#          'shipments': 10,
#          'CSCE': 10,
#          '31': 10,
#          'inflation': 10,
#          'both': 10,
#          'pound': 10,
#          'domestic': 10,
#          'maintain': 10,
#          'Indian': 10,
#          'basic': 10,
#          'probably': 10,
#          'pacts': 10,
#          'buffer': 10,
#          'West': 10,
#          'through': 10,
#          '20': 10,
#          'limited': 10,
#          'sector': 10,
#          'crops': 10,
#          'late': 10,
#          'attend': 10,
#          'Africa': 10,
#          'MAY': 9,
#          'want': 9,
#          'traditional': 9,
#          '90': 9,
#          'association': 9,
#          'On': 9,
#          'slightly': 9,
#          'date': 9,
#          'AT': 9,
#          'Prices': 9,
#          'auction': 9,
#          'offered': 9,
#          'tonne': 9,
#          'value': 9,
#          'balance': 9,
#          'cash': 9,
#          'immediately': 9,
#          'order': 9,
#          '28': 9,
#          'rather': 9,
#          'weekend': 9,
#          'European': 9,
#          'possible': 9,
#          'expect': 9,
#          'find': 9,
#          'common': 9,
#          'trader': 9,
#          'bring': 9,
#          'loan': 9,
#          'raise': 9,
#          'Horick': 9,
#          'very': 9,
#          'QUOTAS': 9,
#          'accord': 9,
#          'back': 9,
#          'recently': 9,
#          'limits': 9,
#          'estimate': 9,
#          'weather': 9,
#          'weeks': 9,
#          'longer': 9,
#          'pact': 9,
#          'adding': 9,
#          'come': 9,
#          'tomorrow': 9,
#          'Ministry': 9,
#          'company': 9,
#          'yesterday': 9,
#          'these': 9,
#          'capital': 9,
#          'behind': 9,
#          'small': 9,
#          'news': 9,
#          'Martinez': 9,
#          'ON': 9,
#          'collapse': 9,
#          'issue': 9,
#          'SEEN': 9,
#          'scheduled': 9,
#          'bank': 9,
#          'exporting': 9,
#          'prepared': 9,
#          'developing': 9,
#          'conference': 9,
#          'falling': 9,
#          'aimed': 9,
#          'Producers': 9,
#          'supplies': 9,
#          'sharp': 9,
#          'kilos': 9,
#          'caused': 9,
#          'palm': 8,
#          'interest': 8,
#          'December': 8,
#          'nine': 8,
#          'called': 8,
#          'Jorge': 8,
#          'kg': 8,
#          'remain': 8,
#          'RAINFALL': 8,
#          '24': 8,
#          'AB': 8,
#          'held': 8,
#          'overall': 8,
#          'offer': 8,
#          'EXPORTS': 8,
#          'OF': 8,
#          'Ugandan': 8,
#          'several': 8,
#          'hard': 8,
#          'delays': 8,
#          'soluble': 8,
#          'strategy': 8,
#          'reduced': 8,
#          'NEW': 8,
#          'details': 8,
#          'unchanged': 8,
#          'July': 8,
#          'accept': 8,
#          'gave': 8,
#          'An': 8,
#          'van': 8,
#          'negotiating': 8,
#          'almost': 8,
#          'Salvador': 8,
#          'must': 8,
#          'might': 8,
#          'prospects': 8,
#          'discussions': 8,
#          'less': 8,
#          'daily': 8,
#          '33': 8,
#          'normal': 8,
#          'firm': 8,
#          'deficit': 8,
#          'firms': 8,
#          'industry': 8,
#          'key': 8,
#          'then': 8,
#          'beans': 8,
#          'proposals': 8,
#          'external': 8,
#          'rate': 8,
#          'lead': 8,
#          'well': 8,
#          'Corp': 8,
#          '85': 8,
#          'agricultural': 8,
#          'run': 8,
#          'short': 8,
#          'ago': 8,
#          'noted': 8,
#          'wanted': 8,
#          'put': 8,
#          'registration': 8,
#          'target': 8,
#          'trends': 8,
#          'losses': 8,
#          'negotiate': 8,
#          'cent': 8,
#          'deliveries': 8,
#          'Ouko': 8,
#          'half': 8,
#          'level': 8,
#          'decision': 7,
#          'delivery': 7,
#          'later': 7,
#          'decisions': 7,
#          '23': 7,
#          'expand': 7,
#          'Foreign': 7,
#          'what': 7,
#          'products': 7,
#          'reached': 7,
#          'manager': 7,
#          'REGISTRATIONS': 7,
#          'growers': 7,
#          'steady': 7,
#          '14': 7,
#          '21': 7,
#          'C': 7,
#          'FALL': 7,
#          'setting': 7,
#          'MARKET': 7,
#          'Marketing': 7,
#          'port': 7,
#          'slide': 7,
#          'growing': 7,
#          'produce': 7,
#          ').': 7,
#          'levels': 7,
#          'point': 7,
#          'side': 7,
#          'ground': 7,
#          'hope': 7,
#          'companies': 7,
#          'part': 7,
#          'yet': 7,
#          'Dutch': 7,
#          'too': 7,
#          'reality': 7,
#          'El': 7,
#          'changes': 7,
#          'BRAZIL': 7,
#          'November': 7,
#          'conditions': 7,
#          'lowest': 7,
#          'announced': 7,
#          'improve': 7,
#          'importers': 7,
#          'believe': 7,
#          '.,': 7,
#          'buy': 7,
#          'review': 7,
#          'working': 7,
#          'verification': 7,
#          'available': 7,
#          '200': 7,
#          'Sugar': 7,
#          'MEETING': 7,
#          'rest': 7,
#          'State': 7,
#          'sought': 7,
#          'Nicaraguan': 7,
#          'Cuenca': 7,
#          'lack': 7,
#          'tried': 7,
#          'spot': 7,
#          'service': 7,
#          'N': 7,
#          'establishing': 7,
#          'resume': 7,
#          'again': 7,
#          'matters': 7,
#          'Honduras': 7,
#          'strike': 7,
#          'operations': 7,
#          'reduction': 7,
#          'wheat': 7,
#          'particularly': 7,
#          'Teck': 7,
#          'Hock': 7,
#          'creditor': 7,
#          'Talks': 7,
#          'debate': 7,
#          'renewed': 7,
#          'financial': 7,
#          'exportable': 7,
#          'sharply': 7,
#          'heavy': 7,
#          'Escalante': 7,
#          'rice': 7,
#          'embassy': 7,
#          'soybean': 7,
#          'Dharyono': 7,
#          'reintegro': 7,
#          'Commodity': 6,
#          'interview': 6,
#          'Trading': 6,
#          'crude': 6,
#          'us': 6,
#          'needed': 6,
#          'development': 6,
#          'encourage': 6,
#          'Officials': 6,
#          'business': 6,
#          'become': 6,
#          '80': 6,
#          'means': 6,
#          'Gilberto': 6,
#          'national': 6,
#          'federation': 6,
#          'volume': 6,
#          'OVER': 6,
#          'better': 6,
#          'quality': 6,
#          '500': 6,
#          '19': 6,
#          'statistics': 6,
#          'planning': 6,
#          'department': 6,
#          'TRADE': 6,
#          'railway': 6,
#          'factor': 6,
#          'asked': 6,
#          'lows': 6,
#          'important': 6,
#          'roastings': 6,
#          'reported': 6,
#          'leaving': 6,
#          'Rio': 6,
#          'biggest': 6,
#          'generally': 6,
#          'favour': 6,
#          'Germany': 6,
#          'old': 6,
#          'roaster': 6,
#          'frost': 6,
#          'responded': 6,
#          'Ivorian': 6,
#          'whether': 6,
#          'where': 6,
#          'described': 6,
#          'rules': 6,
#          'allow': 6,
#          'met': 6,
#          'seek': 6,
#          'near': 6,
#          'Council': 6,
#          'BOARD': 6,
#          'roasted': 6,
#          'processing': 6,
#          'going': 6,
#          'taken': 6,
#          'getting': 6,
#          'led': 6,
#          'result': 6,
#          'general': 6,
#          'net': 6,
#          'fiscal': 6,
#          'soared': 6,
#          'dictate': 6,
#          'soon': 6,
#          'Since': 6,
#          'administrative': 6,
#          'blamed': 6,
#          'funds': 6,
#          'affect': 6,
#          'within': 6,
#          'depressed': 6,
#          'those': 6,
#          'tin': 6,
#          'Delegates': 6,
#          'mean': 6,
#          'splinter': 6,
#          '>,': 6,
#          'try': 6,
#          'night': 6,
#          'investment': 6,
#          'tonight': 6,
#          'she': 6,
#          'believes': 6,
#          'Kaul': 6,
#          'winter': 6,
#          'consumption': 6,
#          'gains': 6,
#          'quintales': 6,
#          'suffer': 6,
#          'loss': 6,
#          'costs': 6,
#          'rail': 6,
#          'either': 5,
#          'introduced': 5,
#          'ahead': 5,
#          'ministry': 5,
#          'Monday': 5,
#          'effort': 5,
#          'hoped': 5,
#          'boost': 5,
#          'contacts': 5,
#          'states': 5,
#          'participation': 5,
#          'plus': 5,
#          'delivered': 5,
#          'stop': 5,
#          '70': 5,
#          'SAYS': 5,
#          'unlimited': 5,
#          'BRAZILIAN': 5,
#          'except': 5,
#          'shillings': 5,
#          'BAGS': 5,
#          'PRICE': 5,
#          '99': 5,
#          'UP': 5,
#          '55': 5,
#          'crisis': 5,
#          'seven': 5,
#          'commercial': 5,
#          'equivalent': 5,
#          'awaiting': 5,
#          'accounts': 5,
#          'areas': 5,
#          'Co': 5,
#          'beginning': 5,
#          'hold': 5,
#          'Dominican': 5,
#          'Republic': 5,
#          'Papua': 5,
#          'Guinea': 5,
#          'central': 5,
#          'press': 5,
#          'estimates': 5,
#          'France': 5,
#          'provide': 5,
#          'Janeiro': 5,
#          'consider': 5,
#          'organization': 5,
#          'calculating': 5,
#          'Although': 5,
#          'attitude': 5,
#          '40': 5,
#          'adopted': 5,
#          'August': 5,
#          'additional': 5,
#          'moving': 5,
#          'benefit': 5,
#          'get': 5,
#          'others': 5,
#          'differences': 5,
#          'representative': 5,
#          'stance': 5,
#          'While': 5,
#          'head': 5,
#          'left': 5,
#          'above': 5,
#          'minimum': 5,
#          'dry': 5,
#          'coming': 5,
#          'services': 5,
#          'scheme': 5,
#          'These': 5,
#          'journalists': 5,
#          'great': 5,
#          'voluntary': 5,
#          'Many': 5,
#          'legislation': 5,
#          'Congress': 5,
#          'Customs': 5,
#          'given': 5,
#          'doesn': 5,
#          'O': 5,
#          'big': 5,
#          'dealers': 5,
#          'SET': 5,
#          'Thursday': 5,
#          'performance': 5,
#          'individual': 5,
#          '65': 5,
#          'Oct': 5,
#          'Sept': 5,
#          'nation': 5,
#          'Banque': 5,
#          'expects': 5,
#          'addition': 5,
#          'vice': 5,
#          'Shearson': 5,
#          'call': 5,
#          'Cesar': 5,
#          'weekly': 5,
#          'growth': 5,
#          '...': 5,
#          'cannot': 5,
#          'immediate': 5,
#          '1984': 5,
#          'deals': 5,
#          'paid': 5,
#          'rupees': 5,
#          'Soviet': 5,
#          'involving': 5,
#          'global': 5,
#          'ships': 5,
#          'contract': 5,
#          'Zimbabwe': 5,
#          'always': 5,
#          'often': 5,
#          'figure': 5,
#          'senior': 5,
#          'Alejandro': 5,
#          'attended': 5,
#          '300': 5,
#          'response': 5,
#          'purchases': 5,
#          'UNLIKELY': 5,
#          'seen': 5,
#          'willing': 5,
#          'know': 5,
#          'wait': 5,
#          'measures': 5,
#          ...})

# %% [markdown]
# Prepare Training Data

# %%
# function was modified to use dynamic window size, with default 2

def generate_skip_grams(corpus, window_size=2):

    skip_grams = []
    for doc in corpus:
        for i, center in enumerate(doc):
            # Determine the range of context words
            start = max(0, i - window_size)
            end = min(len(doc), i + window_size + 1)
            context_words = [doc[j] for j in range(start, end) if j != i]

            # Create skip-grams for the current center word
            for context in context_words:
                skip_grams.append((center, context))
    
    return skip_grams

# Generate skip-grams with a window size of 2
skip_grams = generate_skip_grams(corpus, window_size=2)
print(skip_grams)

skip_grams = []
for doc in corpus:
    for i in range(1, len(doc)-1):
        center = doc[i]
        outside = [doc[i-1], doc[i+1]]
        for each_out in outside:
            skip_grams.append((center, each_out))
skip_grams
# Out:
# [('INDONESIAN', 'COMMODITY'), ('INDONESIAN', 'EXCHANGE'), ('COMMODITY', 'INDONESIAN'), ('COMMODITY', 'EXCHANGE'), ('COMMODITY', 'MAY'), ('EXCHANGE', 'INDONESIAN'), ('EXCHANGE', 'COMMODITY'), ('EXCHANGE', 'MAY'), ('EXCHANGE', 'EXPAND'), ('MAY', 'COMMODITY'), ('MAY', 'EXCHANGE'), ('MAY', 'EXPAND'), ('MAY', 'The'), ('EXPAND', 'EXCHANGE'), ('EXPAND', 'MAY'), ('EXPAND', 'The'), ('EXPAND', 'Indonesian'), ('The', 'MAY'), ('The', 'EXPAND'), ('The', 'Indonesian'), ('The', 'Commodity'), ('Indonesian', 'EXPAND'), ('Indonesian', 'The'), ('Indonesian', 'Commodity'), ('Indonesian', 'Exchange'), ('Commodity', 'The'), ('Commodity', 'Indonesian'), ('Commodity', 'Exchange'), ('Commodity', 'is'), ('Exchange', 'Indonesian'), ('Exchange', 'Commodity'), ('Exchange', 'is'), ('Exchange', 'likely'), ('is', 'Commodity'), ('is', 'Exchange'), ('is', 'likely'), ('is', 'to'), ('likely', 'Exchange'), ('likely', 'is'), ('likely', 'to'), ('likely', 'start'), ('to', 'is'), ('to', 'likely'), ('to', 'start'), ('to', 'trading'), ('start', 'likely'), ('start', 'to'), ('start', 'trading'), ('start', 'in'), ('trading', 'to'), ('trading', 'start'), ('trading', 'in'), ('trading', 'at'), ('in', 'start'), ('in', 'trading'), ('in', 'at'), ('in', 'least'), ('at', 'trading'), ('at', 'in'), ('at', 'least'), ('at', 'one'), ('least', 'in'), ('least', 'at'), ('least', 'one'), ('least', 'new'), ('one', 'at'), ('one', 'least'), ('one', 'new'), ('one', 'commodity'), ('new', 'least'), ('new', 'one'), ('new', 'commodity'), ('new', ','), ('commodity', 'one'), ('commodity', 'new'), ('commodity', ','), ('commodity', 'and'), (',', 'new'), (',', 'commodity'), (',', 'and'), (',', 'possibly'), ('and', 'commodity'), ('and', ','), ('and', 'possibly'), ('and', 'two'), ('possibly', ','), ('possibly', 'and'), ('possibly', 'two'), ('possibly', ','), ('two', 'and'), ('two', 'possibly'), ('two', ','), ('two', 'during'), (',', 'possibly'), (',', 'two'), (',', 'during'), (',', 'calendar'), ('during', 'two'), ('during', ','), ('during', 'calendar'), ('during', '1987'), ('calendar', ','), ('calendar', 'during'), ('calendar', '1987'), ('calendar', ','), ('1987', 'during'), ('1987', 'calendar'), ('1987', ','), ('1987', 'exchange'), (',', 'calendar'), (',', '1987'), (',', 'exchange'), (',', 'chairman'), ('exchange', '1987'), ('exchange', ','), ('exchange', 'chairman'), ('exchange', 'Paian'), ('chairman', ','), ('chairman', 'exchange'), ('chairman', 'Paian'), ('chairman', 'Nainggolan'), ('Paian', 'exchange'), ('Paian', 'chairman'), ('Paian', 'Nainggolan'), ('Paian', 'said'), ('Nainggolan', 'chairman'), ('Nainggolan', 'Paian'), ('Nainggolan', 'said'), ('Nainggolan', '.'), ('said', 'Paian'), ('said', 'Nainggolan'), ('said', '.'), ('.', 'Nainggolan'), ('.', 'said'), ('He', 'told'), ('He', 'Reuters'), ('told', 'He'), ('told', 'Reuters'), ('told', 'in'), ('Reuters', 'He'), ('Reuters', 'told'), ('Reuters', 'in'), ('Reuters', 'a'), ('in', 'told'), ('in', 'Reuters'), ('in', 'a'), ('in', 'telephone'), ('a', 'Reuters'), ('a', 'in'), ('a', 'telephone'), ('a', 'interview'), ('telephone', 'in'), ('telephone', 'a'), ('telephone', 'interview'), ('telephone', 'that'), ('interview', 'a'), ('interview', 'telephone'), ('interview', 'that'), ('interview', 'trading'), ('that', 'telephone'), ('that', 'interview'), ('that', 'trading'), ('that', 'in'), ('trading', 'interview'), ('trading', 'that'), ('trading', 'in'), ('trading', 'palm'), ('in', 'that'), ('in', 'trading'), ('in', 'palm'), ('in', 'oil'), ('palm', 'trading'), ('palm', 'in'), ('palm', 'oil'), ('palm', ','), ('oil', 'in'), ('oil', 'palm'), ('oil', ','), ('oil', 'sawn'), (',', 'palm'), (',', 'oil'), (',', 'sawn'), (',', 'timber'), ('sawn', 'oil'), ('sawn', ','), ('sawn', 'timber'), ('sawn', ','), ('timber', ','), ('timber', 'sawn'), ('timber', ','), ('timber', 'pepper'), (',', 'sawn'), (',', 'timber'), (',', 'pepper'), (',', 'or'), ('pepper', 'timber'), ('pepper', ','), ('pepper', 'or'), ('pepper', 'tobacco'), ('or', ','), ('or', 'pepper'), ('or', 'tobacco'), ('or',  ...
# [('COMMODITY', 'INDONESIAN'),
#  ('COMMODITY', 'EXCHANGE'),
#  ('EXCHANGE', 'COMMODITY'),
#  ('EXCHANGE', 'MAY'),
#  ('MAY', 'EXCHANGE'),
#  ('MAY', 'EXPAND'),
#  ('EXPAND', 'MAY'),
#  ('EXPAND', 'The'),
#  ('The', 'EXPAND'),
#  ('The', 'Indonesian'),
#  ('Indonesian', 'The'),
#  ('Indonesian', 'Commodity'),
#  ('Commodity', 'Indonesian'),
#  ('Commodity', 'Exchange'),
#  ('Exchange', 'Commodity'),
#  ('Exchange', 'is'),
#  ('is', 'Exchange'),
#  ('is', 'likely'),
#  ('likely', 'is'),
#  ('likely', 'to'),
#  ('to', 'likely'),
#  ('to', 'start'),
#  ('start', 'to'),
#  ('start', 'trading'),
#  ('trading', 'start'),
#  ('trading', 'in'),
#  ('in', 'trading'),
#  ('in', 'at'),
#  ('at', 'in'),
#  ('at', 'least'),
#  ('least', 'at'),
#  ('least', 'one'),
#  ('one', 'least'),
#  ('one', 'new'),
#  ('new', 'one'),
#  ('new', 'commodity'),
#  ('commodity', 'new'),
#  ('commodity', ','),
#  (',', 'commodity'),
#  (',', 'and'),
#  ('and', ','),
#  ('and', 'possibly'),
#  ('possibly', 'and'),
#  ('possibly', 'two'),
#  ('two', 'possibly'),
#  ('two', ','),
#  (',', 'two'),
#  (',', 'during'),
#  ('during', ','),
#  ('during', 'calendar'),
#  ('calendar', 'during'),
#  ('calendar', '1987'),
#  ('1987', 'calendar'),
#  ('1987', ','),
#  (',', '1987'),
#  (',', 'exchange'),
#  ('exchange', ','),
#  ('exchange', 'chairman'),
#  ('chairman', 'exchange'),
#  ('chairman', 'Paian'),
#  ('Paian', 'chairman'),
#  ('Paian', 'Nainggolan'),
#  ('Nainggolan', 'Paian'),
#  ('Nainggolan', 'said'),
#  ('said', 'Nainggolan'),
#  ('said', '.'),
#  ('told', 'He'),
#  ('told', 'Reuters'),
#  ('Reuters', 'told'),
#  ('Reuters', 'in'),
#  ('in', 'Reuters'),
#  ('in', 'a'),
#  ('a', 'in'),
#  ('a', 'telephone'),
#  ('telephone', 'a'),
#  ('telephone', 'interview'),
#  ('interview', 'telephone'),
#  ('interview', 'that'),
#  ('that', 'interview'),
#  ('that', 'trading'),
#  ('trading', 'that'),
#  ('trading', 'in'),
#  ('in', 'trading'),
#  ('in', 'palm'),
#  ('palm', 'in'),
#  ('palm', 'oil'),
#  ('oil', 'palm'),
#  ('oil', ','),
#  (',', 'oil'),
#  (',', 'sawn'),
#  ('sawn', ','),
#  ('sawn', 'timber'),
#  ('timber', 'sawn'),
#  ('timber', ','),
#  (',', 'timber'),
#  (',', 'pepper'),
#  ('pepper', ','),
#  ('pepper', 'or'),
#  ('or', 'pepper'),
#  ('or', 'tobacco'),
#  ('tobacco', 'or'),
#  ('tobacco', 'was'),
#  ('was', 'tobacco'),
#  ('was', 'being'),
#  ('being', 'was'),
#  ('being', 'considered'),
#  ('considered', 'being'),
#  ('considered', '.'),
#  ('in', 'Trading'),
#  ('in', 'either'),
#  ('either', 'in'),
#  ('either', 'crude'),
#  ('crude', 'either'),
#  ('crude', 'palm'),
#  ('palm', 'crude'),
#  ('palm', 'oil'),
#  ('oil', 'palm'),
#  ('oil', '('),
#  ('(', 'oil'),
#  ('(', 'CPO'),
#  ('CPO', '('),
#  ('CPO', ')'),
#  (')', 'CPO'),
#  (')', 'or'),
#  ('or', ')'),
#  ('or', 'refined'),
#  ('refined', 'or'),
#  ('refined', 'palm'),
#  ('palm', 'refined'),
#  ('palm', 'oil'),
#  ('oil', 'palm'),
#  ('oil', 'may'),
#  ('may', 'oil'),
#  ('may', 'also'),
#  ('also', 'may'),
#  ('also', 'be'),
#  ('be', 'also'),
#  ('be', 'introduced'),
#  ('introduced', 'be'),
#  ('introduced', '.'),
#  ('he', 'But'),
#  ('he', 'said'),
#  ('said', 'he'),
#  ('said', 'the'),
#  ('the', 'said'),
#  ('the', 'question'),
#  ('question', 'the'),
#  ('question', 'was'),
#  ('was', 'question'),
#  ('was', 'still'),
#  ('still', 'was'),
#  ('still', 'being'),
#  ('being', 'still'),
#  ('being', 'considered'),
#  ('considered', 'being'),
#  ('considered', 'by'),
#  ('by', 'considered'),
#  ('by', 'Trade'),
#  ('Trade', 'by'),
#  ('Trade', 'Minister'),
#  ('Minister', 'Trade'),
#  ('Minister', 'Rachmat'),
#  ('Rachmat', 'Minister'),
#  ('Rachmat', 'Saleh'),
#  ('Saleh', 'Rachmat'),
#  ('Saleh', 'and'),
#  ('and', 'Saleh'),
#  ('and', 'no'),
#  ('no', 'and'),
#  ('no', 'decision'),
#  ('decision', 'no'),
#  ('decision', 'on'),
#  ('on', 'decision'),
#  ('on', 'when'),
#  ('when', 'on'),
#  ('when', 'to'),
#  ('to', 'when'),
#  ('to', 'go'),
#  ('go', 'to'),
#  ('go', 'ahead'),
#  ('ahead', 'go'),
#  ('ahead', 'had'),
#  ('had', 'ahead'),
#  ('had', 'been'),
#  ('been', 'had'),
#  ('been', 'made'),
#  ('made', 'been'),
#  ('made', '.'),
#  ('fledgling', 'The'),
#  ('fledgling', 'exchange'),
#  ('exchange', 'fledgling'),
#  ('exchange', 'currently'),
#  ('currently', 'exchange'),
#  ('currently', 'trades'),
#  ('trades', 'currently'),
#  ('trades', 'coffee'),
#  ('coffee', 'trades'),
#  ('coffee', 'and'),
#  ('and', 'coffee'),
#  ('and', 'rubber'),
#  ('rubber', 'and'),
#  ('rubber', 'physicals'),
#  ('physicals', 'rubber'),
#  ('physicals', 'on'),
#  ('on', 'physicals'),
#  ('on', 'an'),
#  ('an', 'on'),
#  ('an', 'open'),
#  ('open', 'an'),
#  ('open', 'outcry'),
#  ('outcry', 'open'),
#  ('outcry', 'system'),
#  ('system', 'outcry'),
#  ('system', 'four'),
#  ('four', 'system'),
#  ('four', 'days'),
#  ('days', 'four'),
#  ('days', 'a'),
#  ('a', 'days'),
#  ('a', 'week'),
#  ('week', 'a'),
#  ('week', '.'),
#  ('Several', '"'),
#  ('Several', 'factors'),
#  ('factors', 'Several'),
#  ('factors', 'make'),
#  ('make', 'factors'),
#  ('make', 'us'),
#  ('us', 'make'),
#  ('us', 'move'),
#  ('move', 'us'),
#  ('move', 'cautiously'),
#  ('cautiously', 'move'),
#  ('cautiously', ',"'),
#  (',"', 'cautiously'),
#  (',"', 'Nainggolan'),
#  ('Nainggolan', ',"'),
#  ('Nainggolan', 'said'),
#  ('said', 'Nainggolan'),
#  ('said', '.'),
#  ('We', '"'),
#  ('We', 'want'),
#  ('want', 'We'),
#  ('want', 'to'),
#  ('to', 'want'),
#  ('to', 'move'),
#  ('move', 'to'),
#  ('move', 'slowly'),
#  ('slowly', 'move'),
#  ('slowly', 'and'),
#  ('and', 'slowly'),
#  ('and', 'safely'),
#  ('safely', 'and'),
#  ('safely', 'so'),
#  ('so', 'safely'),
#  ('so', 'that'),
#  ('that', 'so'),
#  ('that', 'we'),
#  ('we', 'that'),
#  ('we', 'do'),
#  ('do', 'we'),
#  ('do', 'not'),
#  ('not', 'do'),
#  ('not', 'make'),
#  ('make', 'not'),
#  ('make', 'a'),
#  ('a', 'make'),
#  ('a', 'mistake'),
#  ('mistake', 'a'),
#  ('mistake', 'and'),
#  ('and', 'mistake'),
#  ('and', 'undermine'),
#  ('undermine', 'and'),
#  ('undermine', 'confidence'),
#  ('confidence', 'undermine'),
#  ('confidence', 'in'),
#  ('in', 'confidence'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'exchange'),
#  ('exchange', 'the'),
#  ('exchange', '."'),
#  ('rubber', 'Physical'),
#  ('rubber', 'trading'),
#  ('trading', 'rubber'),
#  ('trading', 'was'),
#  ('was', 'trading'),
#  ('was', 'launched'),
#  ('launched', 'was'),
#  ('launched', 'in'),
#  ('in', 'launched'),
#  ('in', '1985'),
#  ('1985', 'in'),
#  ('1985', ','),
#  (',', '1985'),
#  (',', 'with'),
#  ('with', ','),
#  ('with', 'coffee'),
#  ('coffee', 'with'),
#  ('coffee', 'added'),
#  ('added', 'coffee'),
#  ('added', 'in'),
#  ('in', 'added'),
#  ('in', 'January'),
#  ('January', 'in'),
#  ('January', '1986'),
#  ('1986', 'January'),
#  ('1986', '.'),
#  ('contracts', 'Rubber'),
#  ('contracts', 'are'),
#  ('are', 'contracts'),
#  ('are', 'traded'),
#  ('traded', 'are'),
#  ('traded', 'FOB'),
#  ('FOB', 'traded'),
#  ('FOB', ','),
#  (',', 'FOB'),
#  (',', 'up'),
#  ('up', ','),
#  ('up', 'to'),
#  ('to', 'up'),
#  ('to', 'five'),
#  ('five', 'to'),
#  ('five', 'months'),
#  ('months', 'five'),
#  ('months', 'forward'),
#  ('forward', 'months'),
#  ('forward', '.'),
#  ('coffee', 'Robusta'),
#  ('coffee', 'grades'),
#  ('grades', 'coffee'),
#  ('grades', 'four'),
#  ('four', 'grades'),
#  ('four', 'and'),
#  ('and', 'four'),
#  ('and', 'five'),
#  ('five', 'and'),
#  ('five', 'are'),
#  ('are', 'five'),
#  ('are', 'traded'),
#  ('traded', 'are'),
#  ('traded', 'for'),
#  ('for', 'traded'),
#  ('for', 'prompt'),
#  ('prompt', 'for'),
#  ('prompt', 'delivery'),
#  ('delivery', 'prompt'),
#  ('delivery', 'and'),
#  ('and', 'delivery'),
#  ('and', 'up'),
#  ('up', 'and'),
#  ('up', 'to'),
#  ('to', 'up'),
#  ('to', 'five'),
#  ('five', 'to'),
#  ('five', 'months'),
#  ('months', 'five'),
#  ('months', 'forward'),
#  ('forward', 'months'),
#  ('forward', ','),
#  (',', 'forward'),
#  (',', 'exchange'),
#  ('exchange', ','),
#  ('exchange', 'officials'),
#  ('officials', 'exchange'),
#  ('officials', 'said'),
#  ('said', 'officials'),
#  ('said', '.'),
#  ('trade', 'The'),
#  ('trade', 'ministry'),
#  ('ministry', 'trade'),
#  ('ministry', 'and'),
#  ('and', 'ministry'),
#  ('and', 'exchange'),
#  ('exchange', 'and'),
#  ('exchange', 'board'),
#  ('board', 'exchange'),
#  ('board', 'are'),
#  ('are', 'board'),
#  ('are', 'considering'),
#  ('considering', 'are'),
#  ('considering', 'the'),
#  ('the', 'considering'),
#  ('the', 'introduction'),
#  ('introduction', 'the'),
#  ('introduction', 'of'),
#  ('of', 'introduction'),
#  ('of', 'futures'),
#  ('futures', 'of'),
#  ('futures', 'trading'),
#  ('trading', 'futures'),
#  ('trading', 'later'),
#  ('later', 'trading'),
#  ('later', 'for'),
#  ('for', 'later'),
#  ('for', 'rubber'),
#  ('rubber', 'for'),
#  ('rubber', ','),
#  (',', 'rubber'),
#  (',', 'but'),
#  ('but', ','),
#  ('but', 'one'),
#  ('one', 'but'),
#  ('one', 'official'),
#  ('official', 'one'),
#  ('official', 'said'),
#  ('said', 'official'),
#  ('said', 'a'),
#  ('a', 'said'),
#  ('a', 'feasibility'),
#  ('feasibility', 'a'),
#  ('feasibility', 'study'),
#  ('study', 'feasibility'),
#  ('study', 'was'),
#  ('was', 'study'),
#  ('was', 'needed'),
#  ('needed', 'was'),
#  ('needed', 'first'),
#  ('first', 'needed'),
#  ('first', '.'),
#  ('decisions', 'No'),
#  ('decisions', 'are'),
#  ('are', 'decisions'),
#  ('are', 'likely'),
#  ('likely', 'are'),
#  ('likely', 'until'),
#  ('until', 'likely'),
#  ('until', 'after'),
#  ('after', 'until'),
#  ('after', 'Indonesia'),
#  ('Indonesia', 'after'),
#  ('Indonesia', "'"),
#  ("'", 'Indonesia'),
#  ("'", 's'),
#  ('s', "'"),
#  ('s', 'elections'),
#  ('elections', 's'),
#  ('elections', 'on'),
#  ('on', 'elections'),
#  ('on', 'April'),
#  ('April', 'on'),
#  ('April', '23'),
#  ('23', 'April'),
#  ('23', ','),
#  (',', '23'),
#  (',', 'traders'),
#  ('traders', ','),
#  ('traders', 'said'),
#  ('said', 'traders'),
#  ('said', '.'),
#  ('Minister', 'Trade'),
#  ('Minister', 'Saleh'),
#  ('Saleh', 'Minister'),
#  ('Saleh', 'said'),
#  ('said', 'Saleh'),
#  ('said', 'on'),
#  ('on', 'said'),
#  ('on', 'Monday'),
#  ('Monday', 'on'),
#  ('Monday', 'that'),
#  ('that', 'Monday'),
#  ('that', 'Indonesia'),
#  ('Indonesia', 'that'),
#  ('Indonesia', ','),
#  (',', 'Indonesia'),
#  (',', 'as'),
#  ('as', ','),
#  ('as', 'the'),
#  ('the', 'as'),
#  ('the', 'world'),
#  ('world', 'the'),
#  ('world', "'"),
#  ("'", 'world'),
#  ("'", 's'),
#  ('s', "'"),
#  ('s', 'second'),
#  ('second', 's'),
#  ('second', 'largest'),
#  ('largest', 'second'),
#  ('largest', 'producer'),
#  ('producer', 'largest'),
#  ('producer', 'of'),
#  ('of', 'producer'),
#  ('of', 'natural'),
#  ('natural', 'of'),
#  ('natural', 'rubber'),
#  ('rubber', 'natural'),
#  ('rubber', ','),
#  (',', 'rubber'),
#  (',', 'should'),
#  ('should', ','),
#  ('should', 'expand'),
#  ('expand', 'should'),
#  ('expand', 'its'),
#  ('its', 'expand'),
#  ('its', 'rubber'),
#  ('rubber', 'its'),
#  ('rubber', 'marketing'),
#  ('marketing', 'rubber'),
#  ('marketing', 'effort'),
#  ('effort', 'marketing'),
#  ('effort', 'and'),
#  ('and', 'effort'),
#  ('and', 'he'),
#  ('he', 'and'),
#  ('he', 'hoped'),
#  ('hoped', 'he'),
#  ('hoped', 'development'),
#  ('development', 'hoped'),
#  ('development', 'of'),
#  ('of', 'development'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'exchange'),
#  ('exchange', 'the'),
#  ('exchange', 'would'),
#  ('would', 'exchange'),
#  ('would', 'help'),
#  ('help', 'would'),
#  ('help', 'this'),
#  ('this', 'help'),
#  ('this', '.'),
#  ('said', 'Nainggolan'),
#  ('said', 'that'),
#  ('that', 'said'),
#  ('that', 'the'),
#  ('the', 'that'),
#  ('the', 'exchange'),
#  ('exchange', 'the'),
#  ('exchange', 'was'),
#  ('was', 'exchange'),
#  ('was', 'trying'),
#  ('trying', 'was'),
#  ('trying', 'to'),
#  ('to', 'trying'),
#  ('to', 'boost'),
#  ('boost', 'to'),
#  ('boost', 'overseas'),
#  ('overseas', 'boost'),
#  ('overseas', 'interest'),
#  ('interest', 'overseas'),
#  ('interest', 'by'),
#  ('by', 'interest'),
#  ('by', 'building'),
#  ('building', 'by'),
#  ('building', 'up'),
#  ('up', 'building'),
#  ('up', 'contacts'),
#  ('contacts', 'up'),
#  ('contacts', 'with'),
#  ('with', 'contacts'),
#  ('with', 'end'),
#  ('end', 'with'),
#  ('end', '-'),
#  ('-', 'end'),
#  ('-', 'users'),
#  ('users', '-'),
#  ('users', '.'),
#  ('said', 'He'),
#  ('said', 'teams'),
#  ('teams', 'said'),
#  ('teams', 'had'),
#  ('had', 'teams'),
#  ('had', 'already'),
#  ('already', 'had'),
#  ('already', 'been'),
#  ('been', 'already'),
#  ('been', 'to'),
#  ('to', 'been'),
#  ('to', 'South'),
#  ('South', 'to'),
#  ('South', 'Korea'),
#  ('Korea', 'South'),
#  ('Korea', 'and'),
#  ('and', 'Korea'),
#  ('and', 'Taiwan'),
#  ('Taiwan', 'and'),
#  ('Taiwan', 'to'),
#  ('to', 'Taiwan'),
#  ('to', 'encourage'),
#  ('encourage', 'to'),
#  ('encourage', 'direct'),
#  ('direct', 'encourage'),
#  ('direct', 'use'),
#  ('use', 'direct'),
#  ('use', 'of'),
#  ('of', 'use'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'exchange'),
#  ('exchange', 'the'),
#  ('exchange', ','),
#  (',', 'exchange'),
#  (',', 'while'),
#  ('while', ','),
#  ('while', 'a'),
#  ('a', 'while'),
#  ('a', 'delegation'),
#  ('delegation', 'a'),
#  ('delegation', 'would'),
#  ('would', 'delegation'),
#  ('would', 'also'),
#  ('also', 'would'),
#  ('also', 'visit'),
#  ('visit', 'also'),
#  ('visit', 'Europe'),
#  ('Europe', 'visit'),
#  ('Europe', ','),
#  (',', 'Europe'),
#  (',', 'Mexico'),
#  ('Mexico', ','),
#  ('Mexico', 'and'),
#  ('and', 'Mexico'),
#  ('and', 'some'),
#  ('some', 'and'),
#  ('some', 'Latin'),
#  ('Latin', 'some'),
#  ('Latin', 'American'),
#  ('American', 'Latin'),
#  ('American', 'states'),
#  ('states', 'American'),
#  ('states', 'to'),
#  ('to', 'states'),
#  ('to', 'encourage'),
#  ('encourage', 'to'),
#  ('encourage', 'participation'),
#  ('participation', 'encourage'),
#  ('participation', '.'),
#  ('say', 'Officials'),
#  ('say', 'the'),
#  ('the', 'say'),
#  ('the', 'infant'),
#  ('infant', 'the'),
#  ('infant', 'exchange'),
#  ('exchange', 'infant'),
#  ('exchange', 'has'),
#  ('has', 'exchange'),
#  ('has', 'made'),
#  ('made', 'has'),
#  ('made', 'a'),
#  ('a', 'made'),
#  ('a', 'good'),
#  ('good', 'a'),
#  ('good', 'start'),
#  ('start', 'good'),
#  ('start', 'although'),
#  ('although', 'start'),
#  ('although', 'trading'),
#  ('trading', 'although'),
#  ('trading', 'in'),
#  ('in', 'trading'),
#  ('in', 'coffee'),
#  ('coffee', 'in'),
#  ('coffee', 'has'),
#  ('has', 'coffee'),
#  ('has', 'been'),
#  ('been', 'has'),
#  ('been', 'disappointing'),
#  ('disappointing', 'been'),
#  ('disappointing', '.'),
#  ('in', 'Transactions'),
#  ('in', 'rubber'),
#  ('rubber', 'in'),
#  ('rubber', 'between'),
#  ('between', 'rubber'),
#  ('between', 'the'),
#  ('the', 'between'),
#  ('the', 'start'),
#  ('start', 'the'),
#  ('start', 'of'),
#  ('of', 'start'),
#  ('of', 'trading'),
#  ('trading', 'of'),
#  ('trading', 'in'),
#  ('in', 'trading'),
#  ('in', 'April'),
#  ('April', 'in'),
#  ('April', '1985'),
#  ('1985', 'April'),
#  ('1985', 'and'),
#  ('and', '1985'),
#  ('and', 'December'),
#  ('December', 'and'),
#  ('December', '1986'),
#  ('1986', 'December'),
#  ('1986', 'totalled'),
#  ('totalled', '1986'),
#  ('totalled', '9'),
#  ('9', 'totalled'),
#  ('9', ','),
#  (',', '9'),
#  (',', '595'),
#  ('595', ','),
#  ('595', 'tonnes'),
#  ('tonnes', '595'),
#  ('tonnes', ','),
#  (',', 'tonnes'),
#  (',', 'worth'),
#  ('worth', ','),
#  ('worth', '6'),
#  ('6', 'worth'),
#  ('6', '.'),
#  ('.', '6'),
#  ('.', '9'),
#  ('9', '.'),
#  ('9', 'mln'),
#  ('mln', '9'),
#  ('mln', 'dlrs'),
#  ('dlrs', 'mln'),
#  ('dlrs', 'FOB'),
#  ('FOB', 'dlrs'),
#  ('FOB', ','),
#  (',', 'FOB'),
#  (',', 'plus'),
#  ('plus', ','),
#  ('plus', '184'),
#  ('184', 'plus'),
#  ('184', '.'),
#  ('.', '184'),
#  ('.', '3'),
#  ('3', '.'),
#  ('3', 'mln'),
#  ('mln', '3'),
#  ('mln', 'rupiah'),
#  ('rupiah', 'mln'),
#  ('rupiah', 'for'),
#  ('for', 'rupiah'),
#  ('for', 'rubber'),
#  ('rubber', 'for'),
#  ('rubber', 'delivered'),
#  ('delivered', 'rubber'),
#  ('delivered', 'locally'),
#  ('locally', 'delivered'),
#  ('locally', ','),
#  (',', 'locally'),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'latest'),
#  ('latest', 'the'),
#  ('latest', 'exchange'),
#  ('exchange', 'latest'),
#  ('exchange', 'report'),
#  ('report', 'exchange'),
#  ('report', 'said'),
#  ('said', 'report'),
#  ('said', '.'),
#  ('in', 'Trading'),
#  ('in', 'coffee'),
#  ('coffee', 'in'),
#  ('coffee', 'in'),
#  ('in', 'coffee'),
#  ('in', 'calendar'),
#  ('calendar', 'in'),
#  ('calendar', '1986'),
#  ('1986', 'calendar'),
#  ('1986', 'amounted'),
#  ('amounted', '1986'),
#  ('amounted', 'to'),
#  ('to', 'amounted'),
#  ('to', 'only'),
#  ('only', 'to'),
#  ('only', '1'),
#  ('1', 'only'),
#  ('1', ','),
#  (',', '1'),
#  (',', '905'),
#  ('905', ','),
#  ('905', 'tonnes'),
#  ('tonnes', '905'),
#  ('tonnes', 'in'),
#  ('in', 'tonnes'),
#  ('in', '381'),
#  ('381', 'in'),
#  ('381', 'lots'),
#  ('lots', '381'),
#  ('lots', ','),
#  (',', 'lots'),
#  (',', 'valued'),
#  ('valued', ','),
#  ('valued', 'at'),
#  ('at', 'valued'),
#  ('at', '6'),
#  ('6', 'at'),
#  ('6', '.'),
#  ('.', '6'),
#  ('.', '87'),
#  ('87', '.'),
#  ('87', 'billion'),
#  ('billion', '87'),
#  ('billion', 'rupiah'),
#  ('rupiah', 'billion'),
#  ('rupiah', '.'),
#  ('membership', 'Total'),
#  ('membership', 'of'),
#  ('of', 'membership'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'exchange'),
#  ('exchange', 'the'),
#  ('exchange', 'is'),
#  ('is', 'exchange'),
#  ('is', 'now'),
#  ('now', 'is'),
#  ('now', 'nine'),
#  ('nine', 'now'),
#  ('nine', 'brokers'),
#  ('brokers', 'nine'),
#  ('brokers', 'and'),
#  ('and', 'brokers'),
#  ('and', '44'),
#  ('44', 'and'),
#  ('44', 'traders'),
#  ('traders', '44'),
#  ('traders', '.'),
#  ('BUSINESS', 'COLOMBIA'),
#  ('BUSINESS', 'ASKED'),
#  ('ASKED', 'BUSINESS'),
#  ('ASKED', 'TO'),
#  ('TO', 'ASKED'),
#  ('TO', 'DIVERSIFY'),
#  ('DIVERSIFY', 'TO'),
#  ('DIVERSIFY', 'FROM'),
#  ('FROM', 'DIVERSIFY'),
#  ('FROM', 'COFFEE'),
#  ('COFFEE', 'FROM'),
#  ('COFFEE', 'A'),
#  ('A', 'COFFEE'),
#  ('A', 'Colombia'),
#  ('Colombia', 'A'),
#  ('Colombia', 'government'),
#  ('government', 'Colombia'),
#  ('government', 'trade'),
#  ('trade', 'government'),
#  ('trade', 'official'),
#  ('official', 'trade'),
#  ('official', 'has'),
#  ('has', 'official'),
#  ('has', 'urged'),
#  ('urged', 'has'),
#  ('urged', 'the'),
#  ('the', 'urged'),
#  ('the', 'business'),
#  ('business', 'the'),
#  ('business', 'community'),
#  ('community', 'business'),
#  ('community', 'to'),
#  ('to', 'community'),
#  ('to', 'aggressively'),
#  ('aggressively', 'to'),
#  ('aggressively', 'diversify'),
#  ('diversify', 'aggressively'),
#  ('diversify', 'its'),
#  ('its', 'diversify'),
#  ('its', 'activities'),
#  ('activities', 'its'),
#  ('activities', 'and'),
#  ('and', 'activities'),
#  ('and', 'stop'),
#  ('stop', 'and'),
#  ('stop', 'relying'),
#  ('relying', 'stop'),
#  ('relying', 'so'),
#  ('so', 'relying'),
#  ('so', 'heavily'),
#  ('heavily', 'so'),
#  ('heavily', 'on'),
#  ('on', 'heavily'),
#  ('on', 'coffee'),
#  ('coffee', 'on'),
#  ('coffee', '.'),
#  ('Alberto', 'Samuel'),
#  ('Alberto', 'Yohai'),
#  ('Yohai', 'Alberto'),
#  ('Yohai', ','),
#  (',', 'Yohai'),
#  (',', 'director'),
#  ('director', ','),
#  ('director', 'of'),
#  ('of', 'director'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'Foreign'),
#  ('Foreign', 'the'),
#  ('Foreign', 'Trade'),
#  ('Trade', 'Foreign'),
#  ('Trade', 'Institute'),
#  ('Institute', 'Trade'),
#  ('Institute', ','),
#  (',', 'Institute'),
#  (',', 'INCOMEX'),
#  ('INCOMEX', ','),
#  ('INCOMEX', ','),
#  (',', 'INCOMEX'),
#  (',', 'said'),
#  ('said', ','),
#  ('said', 'private'),
#  ('private', 'said'),
#  ('private', 'businessmen'),
#  ('businessmen', 'private'),
#  ('businessmen', 'should'),
#  ('should', 'businessmen'),
#  ('should', 'not'),
#  ('not', 'should'),
#  ('not', 'become'),
#  ('become', 'not'),
#  ('become', 'what'),
#  ('what', 'become'),
#  ('what', 'he'),
#  ('he', 'what'),
#  ('he', 'called'),
#  ('called', 'he'),
#  ('called', '"'),
#  ('"', 'called'),
#  ('"', 'mental'),
#  ('mental', '"'),
#  ('mental', 'hostages'),
#  ('hostages', 'mental'),
#  ('hostages', '"'),
#  ('"', 'hostages'),
#  ('"', 'to'),
#  ('to', '"'),
#  ('to', 'coffee'),
#  ('coffee', 'to'),
#  ('coffee', ','),
#  (',', 'coffee'),
#  (',', 'traditionally'),
#  ('traditionally', ','),
#  ('traditionally', 'Colombia'),
#  ('Colombia', 'traditionally'),
#  ('Colombia', "'"),
#  ("'", 'Colombia'),
#  ("'", 's'),
#  ('s', "'"),
#  ('s', 'major'),
#  ('major', 's'),
#  ('major', 'export'),
#  ('export', 'major'),
#  ('export', '.'),
#  ('National', 'The'),
#  ('National', 'Planning'),
#  ('Planning', 'National'),
#  ('Planning', 'Department'),
#  ('Department', 'Planning'),
#  ('Department', 'forecast'),
#  ('forecast', 'Department'),
#  ('forecast', 'that'),
#  ('that', 'forecast'),
#  ('that', 'in'),
#  ('in', 'that'),
#  ('in', '1987'),
#  ('1987', 'in'),
#  ('1987', 'coffee'),
#  ('coffee', '1987'),
#  ('coffee', 'will'),
#  ('will', 'coffee'),
#  ('will', 'account'),
#  ('account', 'will'),
#  ('account', 'for'),
#  ('for', 'account'),
#  ('for', 'only'),
#  ('only', 'for'),
#  ('only', 'one'),
#  ('one', 'only'),
#  ('one', '-'),
#  ('-', 'one'),
#  ('-', 'third'),
#  ('third', '-'),
#  ('third', 'of'),
#  ('of', 'third'),
#  ('of', 'total'),
#  ('total', 'of'),
#  ('total', 'exports'),
#  ('exports', 'total'),
#  ('exports', ','),
#  (',', 'exports'),
#  (',', 'or'),
#  ('or', ','),
#  ('or', 'about'),
#  ('about', 'or'),
#  ('about', '1'),
#  ('1', 'about'),
#  ('1', '.'),
#  ('.', '1'),
#  ('.', '5'),
#  ('5', '.'),
#  ('5', 'billion'),
#  ('billion', '5'),
#  ('billion', 'dlrs'),
#  ('dlrs', 'billion'),
#  ('dlrs', ','),
#  (',', 'dlrs'),
#  (',', 'with'),
#  ('with', ','),
#  ('with', 'oil'),
#  ('oil', 'with'),
#  ('oil', 'and'),
#  ('and', 'oil'),
#  ('and', 'energy'),
#  ('energy', 'and'),
#  ('energy', 'products'),
#  ...]

# %%
X_ik_skipgrams = Counter(skip_grams)
X_ik_skipgrams
# Out:
# Counter({('said', '.'): 303,
#          ("'", 's'): 224,
#          ('s', "'"): 224,
#          ('of', 'the'): 211,
#          ('the', 'of'): 211,
#          ('S', '.'): 196,
#          ('.', 'S'): 191,
#          (',', 'the'): 135,
#          ('the', ','): 135,
#          ('in', 'the'): 116,
#          ('the', 'in'): 116,
#          ('.', 'U'): 107,
#          ('U', '.'): 97,
#          (',', '000'): 90,
#          ('000', ','): 90,
#          ('International', 'Coffee'): 76,
#          ('Coffee', 'International'): 76,
#          ('export', 'quotas'): 73,
#          ('quotas', 'export'): 73,
#          ('on', 'the'): 65,
#          ('the', 'on'): 65,
#          ('for', 'the'): 64,
#          ('the', 'for'): 64,
#          ('he', 'said'): 63,
#          ('said', 'he'): 63,
#          ('to', 'the'): 58,
#          ('the', 'to'): 58,
#          ('mln', 'bags'): 56,
#          ('bags', 'mln'): 56,
#          ('1', '.'): 52,
#          ('.', '1'): 51,
#          ('they', 'said'): 51,
#          ('said', 'they'): 51,
#          (',', 'said'): 50,
#          ('said', ','): 50,
#          (',', 'but'): 49,
#          ('but', ','): 49,
#          ('said', 'the'): 48,
#          ('the', 'said'): 48,
#          ('.', '5'): 48,
#          ('5', '.'): 48,
#          ('and', 'the'): 48,
#          ('the', 'and'): 48,
#          ('Coffee', 'Organization'): 48,
#          ('Organization', 'Coffee'): 48,
#          ('to', 'be'): 48,
#          ('be', 'to'): 48,
#          ('last', 'year'): 47,
#          ('year', 'last'): 47,
#          (',', 'ICO'): 47,
#          ('ICO', ','): 47,
#          (',', 'and'): 45,
#          ('and', ','): 45,
#          (',', 'which'): 45,
#          ('which', ','): 45,
#          ('quotas', ','): 45,
#          (',', 'quotas'): 45,
#          ('the', 'International'): 44,
#          ('International', 'the'): 44,
#          ('said', 'delegates'): 43,
#          ('delegates', 'said'): 43,
#          ("'", 'Brazil'): 43,
#          ('by', 'the'): 42,
#          ('the', 'by'): 42,
#          ('sources', 'said'): 42,
#          ('said', 'sources'): 42,
#          ('at', 'the'): 42,
#          ('the', 'at'): 42,
#          ('will', 'be'): 41,
#          ('be', 'will'): 41,
#          ('the', 'ICO'): 41,
#          ('ICO', 'the'): 41,
#          ('the', 'market'): 40,
#          ('market', 'the'): 40,
#          (',', 'they'): 39,
#          ('they', ','): 39,
#          ('Brazil', "'"): 39,
#          ('1', ','): 38,
#          (',', '1'): 38,
#          ('added', '.'): 36,
#          ('with', 'the'): 36,
#          ('the', 'with'): 36,
#          ('000', 'tonnes'): 36,
#          ('tonnes', '000'): 36,
#          ('in', 'London'): 36,
#          ('London', 'in'): 36,
#          (',', 'he'): 35,
#          ('he', ','): 35,
#          (',"', 'he'): 35,
#          ('he', ',"'): 35,
#          ('the', 'U'): 35,
#          ('U', 'the'): 35,
#          ('pct', 'of'): 34,
#          ('of', 'pct'): 34,
#          ('coffee', ','): 33,
#          (',', 'coffee'): 33,
#          ('would', 'be'): 33,
#          ('be', 'would'): 33,
#          ('this', 'year'): 33,
#          ('year', 'this'): 33,
#          ('.', '0'): 33,
#          ('0', '.'): 33,
#          ('said', 'He'): 32,
#          (',', 'a'): 32,
#          ('a', ','): 32,
#          ('2', '.'): 32,
#          ('told', 'Reuters'): 31,
#          ('Reuters', 'told'): 31,
#          ('coffee', 'prices'): 31,
#          ('prices', 'coffee'): 31,
#          (',', 'Brazil'): 31,
#          ('.', '2'): 30,
#          ('the', 'world'): 29,
#          ('world', 'the'): 29,
#          ('year', ','): 29,
#          (',', 'year'): 29,
#          ('Brazil', ','): 29,
#          ('in', '1986'): 29,
#          ('1986', 'in'): 29,
#          ('mln', 'dlrs'): 28,
#          ('dlrs', 'mln'): 28,
#          ('coffee', 'export'): 27,
#          ('export', 'coffee'): 27,
#          ('1986', '/'): 27,
#          ('/', '1986'): 27,
#          ('(', 'ICO'): 27,
#          ('ICO', '('): 27,
#          ('to', 'agree'): 27,
#          ('agree', 'to'): 27,
#          ('executive', 'board'): 27,
#          ('board', 'executive'): 27,
#          (',', 'delegates'): 27,
#          ('delegates', ','): 27,
#          ('in', 'coffee'): 26,
#          ('coffee', 'in'): 26,
#          ('6', '.'): 26,
#          ('000', 'bags'): 26,
#          ('bags', '000'): 26,
#          ('Coffee', 'Institute'): 26,
#          ('Institute', 'Coffee'): 26,
#          ('/', '87'): 26,
#          ('87', '/'): 26,
#          ('in', '1985'): 25,
#          ('1985', 'in'): 25,
#          (',', 'with'): 25,
#          ('with', ','): 25,
#          ('tonnes', 'in'): 25,
#          ('in', 'tonnes'): 25,
#          ('billion', 'dlrs'): 25,
#          ('dlrs', 'billion'): 25,
#          (',', 'Colombia'): 25,
#          ('with', 'a'): 25,
#          ('a', 'with'): 25,
#          ('the', 'coffee'): 25,
#          ('coffee', 'the'): 25,
#          ('bags', ','): 25,
#          (',', 'bags'): 25,
#          ('.', '6'): 24,
#          ('have', 'been'): 24,
#          ('been', 'have'): 24,
#          ('of', 'coffee'): 24,
#          ('coffee', 'of'): 24,
#          ('the', 'country'): 24,
#          ('country', 'the'): 24,
#          ('ICO', ')'): 24,
#          (')', 'ICO'): 24,
#          ('Coffee', 'Brazilian'): 24,
#          ('on', 'a'): 24,
#          ('a', 'on'): 24,
#          ('said', 'Dauster'): 24,
#          ('The', '"'): 23,
#          ('compared', 'with'): 23,
#          ('with', 'compared'): 23,
#          ('from', 'the'): 23,
#          ('the', 'from'): 23,
#          ('re', '-'): 23,
#          ('-', 're'): 23,
#          ('quotas', '.'): 23,
#          ('Brazilian', 'Coffee'): 23,
#          ('consumers', 'and'): 23,
#          ('and', 'consumers'): 23,
#          ('to', 'a'): 23,
#          ('a', 'to'): 23,
#          ('that', 'the'): 22,
#          ('the', 'that'): 22,
#          ('has', 'been'): 22,
#          ('been', 'has'): 22,
#          ('non', '-'): 22,
#          ('-', 'non'): 22,
#          ('York', 'New'): 22,
#          ('NIL', ','): 22,
#          (',', 'NIL'): 22,
#          ('5', 'mln'): 22,
#          ('mln', '5'): 22,
#          ('year', '.'): 22,
#          ('the', 'government'): 22,
#          ('government', 'the'): 22,
#          (',', 'However'): 22,
#          ('of', 'a'): 22,
#          ('a', 'of'): 22,
#          ('and', 'producers'): 22,
#          ('producers', 'and'): 22,
#          ('the', 'meeting'): 22,
#          ('meeting', 'the'): 22,
#          ('in', '1987'): 21,
#          ('1987', 'in'): 21,
#          ('New', 'York'): 21,
#          ('a', 'new'): 21,
#          ('new', 'a'): 21,
#          ('this', 'week'): 21,
#          ('week', 'this'): 21,
#          ('Coffee', 'Organisation'): 21,
#          ('Organisation', 'Coffee'): 21,
#          ('for', 'a'): 21,
#          ('a', 'for'): 21,
#          (',"', 'one'): 21,
#          ('one', ',"'): 21,
#          ('cents', 'a'): 20,
#          ('a', 'cents'): 20,
#          ('Colombia', ','): 20,
#          ('prices', ','): 20,
#          (',', 'prices'): 20,
#          ('trade', 'sources'): 20,
#          ('sources', 'trade'): 20,
#          ('due', 'to'): 20,
#          ('to', 'due'): 20,
#          (',', 'producers'): 20,
#          ('producers', ','): 20,
#          ('expected', 'to'): 20,
#          ('to', 'expected'): 20,
#          ('likely', 'to'): 19,
#          ('to', 'likely'): 19,
#          ('.', '3'): 19,
#          ('3', '.'): 19,
#          ('on', 'coffee'): 19,
#          ('coffee', 'on'): 19,
#          ("'", 'Colombia'): 19,
#          ('s', 'coffee'): 19,
#          ('coffee', 's'): 19,
#          ('coffee', 'exports'): 19,
#          ('exports', 'coffee'): 19,
#          (',', 'talks'): 19,
#          ('talks', ','): 19,
#          ('Colombia', "'"): 18,
#          ('a', 'lb'): 18,
#          ('lb', 'a'): 18,
#          ('of', 'bags'): 18,
#          ('bags', 'of'): 18,
#          ('dlrs', 'in'): 18,
#          ('in', 'dlrs'): 18,
#          ('1985', '/'): 18,
#          ('/', '1985'): 18,
#          ('meeting', 'of'): 18,
#          ('of', 'meeting'): 18,
#          ('Organization', '('): 18,
#          ('(', 'Organization'): 18,
#          ('the', 'end'): 18,
#          ('end', 'the'): 18,
#          ('end', 'of'): 18,
#          ('of', 'end'): 18,
#          ('will', 'not'): 18,
#          ('not', 'will'): 18,
#          ('the', 'first'): 18,
#          ('first', 'the'): 18,
#          ('Dauster', 'said'): 18,
#          ('on', 'export'): 18,
#          ('export', 'on'): 18,
#          ('failure', 'of'): 18,
#          ('of', 'failure'): 18,
#          ('in', 'a'): 17,
#          ('a', 'in'): 17,
#          ('up', 'to'): 17,
#          ('to', 'up'): 17,
#          ('official', 'said'): 17,
#          ('said', 'official'): 17,
#          ('as', 'the'): 17,
#          ('the', 'as'): 17,
#          ('world', "'"): 17,
#          ("'", 'world'): 17,
#          (',', 'while'): 17,
#          ('while', ','): 17,
#          ('.', '9'): 17,
#          ('9', '.'): 17,
#          ('export', 'registrations'): 17,
#          ('registrations', 'export'): 17,
#          ('president', 'of'): 17,
#          ('of', 'president'): 17,
#          ('.', '50'): 17,
#          ('50', '.'): 17,
#          ('of', 'its'): 17,
#          ('its', 'of'): 17,
#          ('of', 'export'): 17,
#          ('export', 'of'): 17,
#          ('export', 'quota'): 17,
#          ('quota', 'export'): 17,
#          ('producer', ','): 17,
#          (',', 'producer'): 17,
#          ('could', 'be'): 17,
#          ('be', 'could'): 17,
#          ('on', 'quotas'): 17,
#          ('quotas', 'on'): 17,
#          ('as', 'a'): 17,
#          ('a', 'as'): 17,
#          ('he', 'added'): 17,
#          ('added', 'he'): 17,
#          ('have', 'to'): 17,
#          ('to', 'have'): 17,
#          ('Organization', ','): 17,
#          (',', 'Organization'): 17,
#          ('objective', 'criteria'): 17,
#          ('criteria', 'objective'): 17,
#          ('/', '86'): 17,
#          ('86', '/'): 17,
#          ('Dauster', 'Jorio'): 17,
#          ('rise', 'to'): 17,
#          ('to', 'rise'): 17,
#          ('We', '"'): 16,
#          ('last', 'week'): 16,
#          ('week', 'last'): 16,
#          ('the', 'sources'): 16,
#          ('sources', 'the'): 16,
#          ('4', '.'): 16,
#          ('in', 'February'): 16,
#          ('February', 'in'): 16,
#          ('during', 'the'): 16,
#          ('the', 'during'): 16,
#          ('did', 'not'): 16,
#          ('not', 'did'): 16,
#          ('foreign', 'exchange'): 16,
#          ('exchange', 'foreign'): 16,
#          ('Jorio', 'Dauster'): 16,
#          ('today', ','): 16,
#          (',', 'today'): 16,
#          ('.', '00'): 16,
#          ('00', '.'): 16,
#          ('60', '-'): 15,
#          ('-', '60'): 15,
#          ('is', ','): 15,
#          (',', 'is'): 15,
#          ('because', 'of'): 15,
#          ('of', 'because'): 15,
#          ('the', 'current'): 15,
#          ('current', 'the'): 15,
#          (',', 'including'): 15,
#          ('including', ','): 15,
#          ('Costa', 'Rica'): 15,
#          ('Rica', 'Costa'): 15,
#          ('coffee', 'producers'): 15,
#          ('producers', 'coffee'): 15,
#          ('week', ','): 15,
#          (',', 'week'): 15,
#          ('and', 'Brazil'): 15,
#          ('U', 'The'): 15,
#          ('coffee', 'market'): 15,
#          ('market', 'coffee'): 15,
#          ('the', 'IBC'): 15,
#          ('IBC', 'the'): 15,
#          ('.', '4'): 15,
#          ('would', 'not'): 15,
#          ('not', 'would'): 15,
#          ('prices', '.'): 15,
#          ('the', 'failure'): 15,
#          ('failure', 'the'): 15,
#          ('had', 'been'): 14,
#          ('been', 'had'): 14,
#          (',', 'as'): 14,
#          ('as', ','): 14,
#          ('said', 'that'): 14,
#          ('that', 'said'): 14,
#          (',', 'Mexico'): 14,
#          ('Mexico', ','): 14,
#          ('exports', ','): 14,
#          (',', 'exports'): 14,
#          (',', 'it'): 14,
#          ('it', ','): 14,
#          ('pct', 'in'): 14,
#          ('in', 'pct'): 14,
#          ('group', 'of'): 14,
#          ('of', 'group'): 14,
#          ('based', 'on'): 14,
#          ('on', 'based'): 14,
#          ('said', 'in'): 14,
#          ('in', 'said'): 14,
#          ('meeting', ','): 14,
#          (',', 'meeting'): 14,
#          ('Brazil', 'and'): 14,
#          (',', 'IBC'): 14,
#          ('IBC', ','): 14,
#          ('an', 'agreement'): 14,
#          ('agreement', 'an'): 14,
#          ('last', 'month'): 14,
#          ('month', 'last'): 14,
#          ('to', 'set'): 14,
#          ('set', 'to'): 14,
#          ('failed', 'to'): 14,
#          ('to', 'failed'): 14,
#          ('1986', ','): 14,
#          (',', '1986'): 14,
#          ('countries', ','): 14,
#          (',', 'countries'): 14,
#          ('would', 'have'): 14,
#          ('have', 'would'): 14,
#          ('Latin', 'American'): 13,
#          ('American', 'Latin'): 13,
#          ('bags', 'in'): 13,
#          ('in', 'bags'): 13,
#          ('in', 'New'): 13,
#          ('New', 'in'): 13,
#          (',', 'president'): 13,
#          ('president', ','): 13,
#          ('the', 'new'): 13,
#          ('new', 'the'): 13,
#          ('registrations', 'for'): 13,
#          ('for', 'registrations'): 13,
#          ('the', 'trade'): 13,
#          ('trade', 'the'): 13,
#          ('for', 'coffee'): 13,
#          ('coffee', 'for'): 13,
#          (',', 'compared'): 13,
#          ('compared', ','): 13,
#          ('producing', 'countries'): 13,
#          ('countries', 'producing'): 13,
#          ('over', 'the'): 13,
#          ('the', 'over'): 13,
#          (',', '"'): 13,
#          ('"', ','): 13,
#          ('to', 'continue'): 13,
#          ('continue', 'to'): 13,
#          ('but', 'the'): 13,
#          ('the', 'but'): 13,
#          ('in', 'Brazil'): 13,
#          ('Brazil', 'in'): 13,
#          ('agree', 'on'): 13,
#          ('on', 'agree'): 13,
#          ('has', 'Brazil'): 13,
#          ('does', 'not'): 13,
#          ('not', 'does'): 13,
#          ('such', 'as'): 13,
#          ('as', 'such'): 13,
#          ('Coast', 'Ivory'): 13,
#          ('its', 'coffee'): 13,
#          ('coffee', 'its'): 13,
#          ('30', 'pct'): 13,
#          ('pct', '30'): 13,
#          ('at', 'least'): 12,
#          ('least', 'at'): 12,
#          ('Institute', ','): 12,
#          (',', 'Institute'): 12,
#          ('National', 'Coffee'): 12,
#          ('Coffee', 'National'): 12,
#          ('not', 'to'): 12,
#          ('to', 'not'): 12,
#          ('said', 'it'): 12,
#          ('it', 'said'): 12,
#          ('more', 'than'): 12,
#          ('than', 'more'): 12,
#          ('the', 'year'): 12,
#          ('year', 'the'): 12,
#          ('green', 'coffee'): 12,
#          ('coffee', 'green'): 12,
#          ('said', 'Brazil'): 12,
#          ('be', 'a'): 12,
#          ('a', 'be'): 12,
#          ('quota', 'shares'): 12,
#          ('shares', 'quota'): 12,
#          ('the', 'London'): 12,
#          ('London', 'the'): 12,
#          (',', 'who'): 12,
#          ('who', ','): 12,
#          (',', 'an'): 12,
#          ('an', ','): 12,
#          ('bags', '.'): 12,
#          ('trade', ','): 12,
#          (',', 'trade'): 12,
#          ('the', 'quota'): 12,
#          ('quota', 'the'): 12,
#          (',', 'to'): 12,
#          ('to', ','): 12,
#          ('country', "'"): 12,
#          ("'", 'country'): 12,
#          ('&', 'lt'): 12,
#          ('lt', '&'): 12,
#          ('lt', ';'): 12,
#          (';', 'lt'): 12,
#          ('a', 'year'): 12,
#          ('year', 'a'): 12,
#          ('.', '7'): 12,
#          ('7', '.'): 12,
#          ('ICO', 'executive'): 12,
#          ('executive', 'ICO'): 12,
#          ('to', 'discuss'): 12,
#          ('discuss', 'to'): 12,
#          ('according', 'to'): 12,
#          ('to', 'according'): 12,
#          ('is', 'expected'): 12,
#          ('expected', 'is'): 12,
#          ('board', 'meeting'): 12,
#          ('meeting', 'board'): 12,
#          ('the', 'Brazilian'): 12,
#          ('Brazilian', 'the'): 12,
#          ('"', 'C'): 12,
#          ('C', '"'): 12,
#          ('the', 'talks'): 12,
#          ('talks', 'the'): 12,
#          ('Colombia', 'and'): 12,
#          ('and', 'Colombia'): 12,
#          ('fall', 'to'): 12,
#          ('to', 'fall'): 12,
#          ('1985', ','): 11,
#          (',', '1985'): 11,
#          ('tonnes', ','): 11,
#          (',', 'tonnes'): 11,
#          ('in', 'calendar'): 11,
#          ('calendar', 'in'): 11,
#          ('market', ','): 11,
#          (',', 'market'): 11,
#          ('one', 'of'): 11,
#          ('of', 'one'): 11,
#          ('Reuters', '.'): 11,
#          ('coffee', 'year'): 11,
#          ('year', 'coffee'): 11,
#          ('50', '('): 11,
#          ('(', '50'): 11,
#          ('Uganda', "'"): 11,
#          ("'", 'Uganda'): 11,
#          ('it', 'is'): 11,
#          ('is', 'it'): 11,
#          ('talks', 'in'): 11,
#          ('in', 'talks'): 11,
#          ('were', 'suspended'): 11,
#          ('suspended', 'were'): 11,
#          ('and', 'producer'): 11,
#          ('producer', 'and'): 11,
#          ('Ivory', 'Coast'): 11,
#          ('of', 'quotas'): 11,
#          ('quotas', 'of'): 11,
#          ('"', 'objective'): 11,
#          ('objective', '"'): 11,
#          ('said', 'exporters'): 11,
#          ('exporters', 'said'): 11,
#          ('need', 'to'): 11,
#          ('to', 'need'): 11,
#          ('agreement', 'on'): 11,
#          ('on', 'agreement'): 11,
#          ('Brazil', 'said'): 11,
#          ("'", 't'): 11,
#          ('t', "'"): 11,
#          ('ICO', 'The'): 11,
#          ('to', 'sell'): 11,
#          ('sell', 'to'): 11,
#          ('talks', 'ICO'): 11,
#          ('to', 'make'): 11,
#          ('make', 'to'): 11,
#          ('how', 'to'): 11,
#          ('to', 'how'): 11,
#          (',', 'Honduras'): 11,
#          ('Honduras', ','): 11,
#          ('(', 'NA'): 11,
#          ('NA', '('): 11,
#          ('NA', ')'): 11,
#          ('calendar', '1987'): 10,
#          ('1987', 'calendar'): 10,
#          ('told', 'He'): 10,
#          ('in', 'January'): 10,
#          ('January', 'in'): 10,
#          ('1986', '.'): 10,
#          ('Coffee', 'Growers'): 10,
#          ('Growers', 'Coffee'): 10,
#          ('Arango', ','): 10,
#          (',', 'Arango'): 10,
#          ('for', 'an'): 10,
#          ('an', 'for'): 10,
#          ('the', 'same'): 10,
#          ('same', 'the'): 10,
#          ('.', '8'): 10,
#          ('8', '.'): 10,
#          ('in', 'prices'): 10,
#          ('prices', 'in'): 10,
#          ('the', 'week'): 10,
#          ('week', 'the'): 10,
#          ('set', 'for'): 10,
#          ('for', 'set'): 10,
#          ('Institute', '('): 10,
#          ('(', 'Institute'): 10,
#          ('the', 'next'): 10,
#          ('next', 'the'): 10,
#          ('countries', '.'): 10,
#          ('members', 'of'): 10,
#          ('of', 'members'): 10,
#          ('Coffee', 'Agreement'): 10,
#          ('Agreement', 'Coffee'): 10,
#          ('meeting', 'in'): 10,
#          ('in', 'meeting'): 10,
#          ('Brazilian', 'The'): 10,
#          ('Brazil', 'has'): 10,
#          ('year', "'"): 10,
#          ("'", 'year'): 10,
#          ('there', 'is'): 10,
#          ('is', 'there'): 10,
#          ('in', 'an'): 10,
#          ('an', 'in'): 10,
#          ('not', 'be'): 10,
#          ('be', 'not'): 10,
#          ('under', 'the'): 10,
#          ('the', 'under'): 10,
#          ('Dauster', ','): 10,
#          (',', 'Dauster'): 10,
#          ('United', 'States'): 10,
#          ('States', 'United'): 10,
#          ('to', 'reach'): 10,
#          ('reach', 'to'): 10,
#          ('are', 'not'): 10,
#          ('not', 'are'): 10,
#          (',', 'in'): 10,
#          ('in', ','): 10,
#          ('stocks', 'and'): 10,
#          ('and', 'stocks'): 10,
#          ('April', '1'): 10,
#          ('1', 'April'): 10,
#          ('market', 'situation'): 10,
#          ('situation', 'market'): 10,
#          ('to', 'export'): 10,
#          ('export', 'to'): 10,
#          ('told', 'reporters'): 10,
#          ('reporters', 'told'): 10,
#          ('to', 'meet'): 10,
#          ('meet', 'to'): 10,
#          ('10', '.'): 10,
#          ('.', '10'): 10,
#          ('Kenya', "'"): 10,
#          ("'", 'Kenya'): 10,
#          ('broke', 'down'): 10,
#          ('down', 'broke'): 10,
#          ('talks', 'on'): 10,
#          ('on', 'talks'): 10,
#          ('N', '.'): 10,
#          ('that', 'Brazil'): 10,
#          ('Brazil', 'that'): 10,
#          (',', 'according'): 10,
#          ('according', ','): 10,
#          ('which', 'would'): 10,
#          ('would', 'which'): 10,
#          (',', 'U'): 10,
#          ('U', ','): 10,
#          ('0', 'mln'): 10,
#          ('mln', '0'): 10,
#          (',', 'Guatemala'): 10,
#          ('Guatemala', ','): 10,
#          ('Cherry', '"'): 10,
#          ('"', 'Cherry'): 10,
#          (')', 'NA'): 10,
#          ('mln', 'tonnes'): 10,
#          ('tonnes', 'mln'): 10,
#          ('is', 'likely'): 9,
#          ('likely', 'is'): 9,
#          ('coffee', 'and'): 9,
#          ('and', 'coffee'): 9,
#          ('officials', 'said'): 9,
#          ('said', 'officials'): 9,
#          ('rubber', ','): 9,
#          (',', 'rubber'): 9,
#          ("'", 'Indonesia'): 9,
#          (',', 'or'): 9,
#          ('or', ','): 9,
#          ('at', 'a'): 9,
#          ('a', 'at'): 9,
#          ('production', 'and'): 9,
#          ('and', 'production'): 9,
#          ('is', 'not'): 9,
#          ('not', 'is'): 9,
#          ('May', 'for'): 9,
#          ('for', 'May'): 9,
#          (',', 'we'): 9,
#          ('we', ','): 9,
#          (',', 'will'): 9,
#          ('will', ','): 9,
#          ('export', 'earnings'): 9,
#          ('earnings', 'export'): 9,
#          ('September', '30'): 9,
#          ('30', 'September'): 9,
#          ('-', 'kilo'): 9,
#          ('kilo', '-'): 9,
#          ('of', 'last'): 9,
#          ('last', 'of'): 9,
#          ('Organisation', '('): 9,
#          ('(', 'Organisation'): 9,
#          (',', 'India'): 9,
#          ('India', ','): 9,
#          ('the', 'past'): 9,
#          ('past', 'the'): 9,
#          ('is', 'to'): 9,
#          ('to', 'is'): 9,
#          ('of', 'Brazil'): 9,
#          ('Brazil', 'of'): 9,
#          ('its', 'export'): 9,
#          ('export', 'its'): 9,
#          ('coffee', 'quotas'): 9,
#          ('quotas', 'coffee'): 9,
#          (',', 'has'): 9,
#          ('has', ','): 9,
#          ('-', 'introduction'): 9,
#          ('introduction', '-'): 9,
#          ('officials', '.'): 9,
#          ('suspended', 'in'): 9,
#          ('in', 'suspended'): 9,
#          ('as', 'long'): 9,
#          ('long', 'as'): 9,
#          ('is', 'Brazil'): 9,
#          ('a', 'compromise'): 9,
#          ('compromise', 'a'): 9,
#          ('in', 'September'): 9,
#          ('September', 'in'): 9,
#          ('The', 'Brazilian'): 9,
#          ('used', 'to'): 9,
#          ('to', 'used'): 9,
#          ('is', 'a'): 9,
#          ('a', 'is'): 9,
#          (',', 'was'): 9,
#          ('was', ','): 9,
#          ('quota', 'system'): 9,
#          ('system', 'quota'): 9,
#          ('quota', 'distribution'): 9,
#          ('distribution', 'quota'): 9,
#          ('could', 'not'): 9,
#          ('not', 'could'): 9,
#          ('coffee', 'production'): 9,
#          ('production', 'coffee'): 9,
#          ('this', 'month'): 9,
#          ('month', 'this'): 9,
#          ('the', 'previous'): 9,
#          ('previous', 'the'): 9,
#          ('of', 'foreign'): 9,
#          ('foreign', 'of'): 9,
#          (',', 'are'): 9,
#          ('are', ','): 9,
#          ('should', 'be'): 9,
#          ('be', 'should'): 9,
#          (',', 'told'): 9,
#          ('told', ','): 9,
#          ('the', 'United'): 9,
#          ('United', 'the'): 9,
#          ('world', 'coffee'): 9,
#          ('coffee', 'world'): 9,
#          ('It', '"'): 9,
#          ('adding', ','): 9,
#          (',', 'adding'): 9,
#          ('-', 'member'): 9,
#          ('member', '-'): 9,
#          ('share', 'of'): 9,
#          ('of', 'share'): 9,
#          ('(', 'IBC'): 9,
#          ('IBC', '('): 9,
#          ('IBC', ')'): 9,
#          (')', 'IBC'): 9,
#          ('after', 'the'): 9,
#          ('the', 'after'): 9,
#          ('the', 'state'): 9,
#          ('state', 'the'): 9,
#          ('a', 'pound'): 9,
#          ('pound', 'a'): 9,
#          (',', 'tea'): 9,
#          ('tea', ','): 9,
#          ('exports', 'to'): 9,
#          ('to', 'exports'): 9,
#          ('producers', 'to'): 9,
#          ('to', 'producers'): 9,
#          ('fall', 'in'): 9,
#          ('in', 'fall'): 9,
#          ('.', 'N'): 9,
#          ('ICO', 'talks'): 9,
#          ('down', ','): 9,
#          (',', 'down'): 9,
#          ('and', 'a'): 9,
#          ('a', 'and'): 9,
#          ('buffer', 'stock'): 9,
#          ('stock', 'buffer'): 9,
#          ('will', 'meet'): 9,
#          ('meet', 'will'): 9,
#          ('aimed', 'at'): 9,
#          ('at', 'aimed'): 9,
#          ('following', 'the'): 9,
#          ('the', 'following'): 9,
#          ('foreign', 'debt'): 9,
#          ('debt', 'foreign'): 9,
#          ('00', '('): 9,
#          ('(', '00'): 9,
#          ('MM', ','): 9,
#          (',', 'MM'): 9,
#          ('the', 'National'): 9,
#          ('National', 'the'): 9,
#          ('the', 'breakdown'): 9,
#          ('breakdown', 'the'): 9,
#          ('1987', ','): 8,
#          (',', '1987'): 8,
#          ('oil', ','): 8,
#          (',', 'oil'): 8,
#          ('to', 'go'): 8,
#          ('go', 'to'): 8,
#          ('week', '.'): 8,
#          ('introduction', 'of'): 8,
#          ('of', 'introduction'): 8,
#          ('said', 'a'): 8,
#          ('a', 'said'): 8,
#          ('traders', 'said'): 8,
#          ('said', 'traders'): 8,
#          ('largest', 'producer'): 8,
#          ('producer', 'largest'): 8,
#          ('to', 'coffee'): 8,
#          ('coffee', 'to'): 8,
#          ('Cardenas', ','): 8,
#          (',', 'Cardenas'): 8,
#          ('Growers', "'"): 8,
#          ("'", 'Growers'): 8,
#          ('(', '60'): 8,
#          ('60', '('): 8,
#          ('1987', '.'): 8,
#          ('there', 'are'): 8,
#          ('are', 'there'): 8,
#          ('private', 'exporters'): 8,
#          ('exporters', 'private'): 8,
#          ('than', 'the'): 8,
#          ('the', 'than'): 8,
#          ('NIL', '.'): 8,
#          (',', 'SAO'): 8,
#          ('SAO', ','): 8,
#          ('was', 'not'): 8,
#          ('not', 'was'): 8,
#          ('the', 'recent'): 8,
#          ('recent', 'the'): 8,
#          ('order', 'in'): 8,
#          ('in', 'order'): 8,
#          ('year', 'and'): 8,
#          ('and', 'year'): 8,
#          ('exporters', ','): 8,
#          (',', 'exporters'): 8,
#          (',', 'Ecuador'): 8,
#          ('Ecuador', ','): 8,
#          ('for', 'quotas'): 8,
#          ('quotas', 'for'): 8,
#          ('rather', 'than'): 8,
#          ('than', 'rather'): 8,
#          ('a', 'meeting'): 8,
#          ('meeting', 'a'): 8,
#          ('new', 'formula'): 8,
#          ('formula', 'new'): 8,
#          (',"', 'the'): 8,
#          ('the', ',"'): 8,
#          ('the', 'official'): 8,
#          ('official', 'the'): 8,
#          ('to', 'pay'): 8,
#          ('pay', 'to'): 8,
#          ('van', 'Horick'): 8,
#          ('Horick', 'van'): 8,
#          ('meeting', '.'): 8,
#          ('consumer', 'and'): 8,
#          ('and', 'consumer'): 8,
#          ('quotas', 'were'): 8,
#          ('were', 'quotas'): 8,
#          ('reintroduction', 'of'): 8,
#          ('of', 'reintroduction'): 8,
#          ('it', 'will'): 8,
#          ('will', 'it'): 8,
#          ('if', 'the'): 8,
#          ('the', 'if'): 8,
#          ('1987', '/'): 8,
#          ('/', '1987'): 8,
#          ('/', '88'): 8,
#          ('88', '/'): 8,
#          ('crop', '.'): 8,
#          ('earlier', 'this'): 8,
#          ('this', 'earlier'): 8,
#          ('government', 'to'): 8,
#          ('to', 'government'): 8,
#          ('no', 'longer'): 8,
#          ('longer', 'no'): 8,
#          ('we', 'have'): 8,
#          ('have', 'we'): 8,
#          ('was', 'a'): 8,
#          ('a', 'was'): 8,
#          ('is', 'It'): 8,
#          (',"', 'said'): 8,
#          ('said', ',"'): 8,
#          ('prices', 'for'): 8,
#          ('for', 'prices'): 8,
#          ('not', 'have'): 8,
#          ('have', 'not'): 8,
#          ('the', 'export'): 8,
#          ('export', 'the'): 8,
#          ('contribution', 'quota'): 8,
#          ('quota', 'contribution'): 8,
#          ('exports', 'and'): 8,
#          ('and', 'exports'): 8,
#          (')', 'and'): 8,
#          ('and', ')'): 8,
#          ('tonnes', 'of'): 8,
#          ('of', 'tonnes'): 8,
#          ('s', 'economy'): 8,
#          ('economy', 's'): 8,
#          ('Brazil', 'would'): 8,
#          ('would', 'Brazil'): 8,
#          ('prices', 'and'): 8,
#          ('and', 'prices'): 8,
#          ('the', 'price'): 8,
#          ('price', 'the'): 8,
#          ('difficult', 'to'): 8,
#          ('to', 'difficult'): 8,
#          ('to', 'maintain'): 8,
#          ('maintain', 'to'): 8,
#          ('of', 'this'): 8,
#          ('this', 'of'): 8,
#          ('American', 'coffee'): 8,
#          ('coffee', 'American'): 8,
#          ('in', 'Managua'): 8,
#          ('Managua', 'in'): 8,
#          ('to', '1'): 8,
#          ('1', 'to'): 8,
#          ('from', '1'): 8,
#          ('1', 'from'): 8,
#          ('a', 'quota'): 8,
#          ('quota', 'a'): 8,
#          ('of', 'International'): 8,
#          ('International', 'of'): 8,
#          ('open', 'to'): 8,
#          ('to', 'open'): 8,
#          ('at', '1'): 8,
#          ('1', 'at'): 8,
#          ('market', 'prices'): 8,
#          ('prices', 'market'): 8,
#          ('prepared', 'to'): 8,
#          ('to', 'prepared'): 8,
#          (',', 'Nicaragua'): 8,
#          ('Nicaragua', ','): 8,
#          ('try', 'to'): 8,
#          ('to', 'try'): 8,
#          ('quotas', 'before'): 8,
#          ('before', 'quotas'): 8,
#          ('and', 'closed'): 8,
#          ('closed', 'and'): 8,
#          ('of', '1'): 8,
#          ('1', 'of'): 8,
#          (')', 'Robusta'): 8,
#          ('Robusta', ')'): 8,
#          ('0', 'MM'): 8,
#          ('MM', '0'): 8,
#          ('11', '.'): 8,
#          ('.', '11'): 8,
#          ('breakdown', 'of'): 8,
#          ('of', 'breakdown'): 8,
#          ('palm', 'oil'): 7,
#          ('oil', 'palm'): 7,
#          ('the', 'exchange'): 7,
#          ('exchange', 'the'): 7,
#          ('are', 'likely'): 7,
#          ('likely', 'are'): 7,
#          ('the', 'start'): 7,
#          ('start', 'the'): 7,
#          ('3', 'mln'): 7,
#          ('mln', '3'): 7,
#          ('account', 'for'): 7,
#          ('for', 'account'): 7,
#          ('of', 'total'): 7,
#          ('total', 'of'): 7,
#          ('Cardenas', 'Jorge'): 7,
#          ("'", 'Federation'): 7,
#          ('Federation', "'"): 7,
#          ('and', 'that'): 7,
#          ('that', 'and'): 7,
#          (')', 'bags'): 7,
#          ('bags', ')'): 7,
#          ('marketing', 'policy'): 7,
#          ('policy', 'marketing'): 7,
#          ('the', 'private'): 7,
#          ('private', 'the'): 7,
#          ("'", 'association'): 7,
#          ('association', "'"): 7,
#          ('and', 'May'): 7,
#          ('May', 'and'): 7,
#          ('said', 'Arango'): 7,
#          ('month', ','): 7,
#          (',', 'month'): 7,
#          ('a', 'total'): 7,
#          ('total', 'a'): 7,
#          ('STATE', ':'): 7,
#          (':', 'STATE'): 7,
#          ('the', 'Coffee'): 7,
#          ('Coffee', 'the'): 7,
#          ('board', 'The'): 7,
#          (',', 'Kenya'): 7,
#          ('Kenya', ','): 7,
#          ('markets', ','): 7,
#          (',', 'markets'): 7,
#          ('.', '15'): 7,
#          ('15', '.'): 7,
#          ('value', 'of'): 7,
#          ('of', 'value'): 7,
#          ('show', '.'): 7,
#          ('dlrs', '.'): 7,
#          ('-', 'coffee'): 7,
#          ('coffee', '-'): 7,
#          ('it', 'was'): 7,
#          ...})

# %% [markdown]
# ### Weighting function
#
# GloVe includes a weighting function to scale down too frequent words.
#
# <img src = "../figures/glove_weighting_func.png" width=400>

# %%
def weighting(w_i, w_j, X_ik):
    
    #check whether the co-occurences between w_i and w_j is available
    try:
        x_ij = X_ik[(w_i, w_j)]
        #if not exist, then set to 1 "laplace smoothing"
    except:
        x_ij = 1
        
    #set xmax
    x_max = 100
    #set alpha
    alpha = 0.75
    
    #if co-ocurrence does not exceeed xmax, then just multiply with some alpha
    if x_ij < x_max:
        result = (x_ij / x_max)**alpha
    #otherwise, set to 1
    else:
        result = 1
    
    return result

# %%
from itertools import combinations_with_replacement

X_ik = {} #keeping the co-occurences
weighting_dic = {} #already scale the co-occurences using the weighting function

for bigram in combinations_with_replacement(vocabs, 2):
    if X_ik_skipgrams.get(bigram):  #if the pair exists in our corpus
        co = X_ik_skipgrams[bigram]
        X_ik[bigram] = co + 1 #for stability
        X_ik[(bigram[1], bigram[0])] = co + 1 #basically apple, banana = banana, apple
    else:
        pass
    
    weighting_dic[bigram] = weighting(bigram[0], bigram[1], X_ik)
    weighting_dic[(bigram[1], bigram[0])] = weighting(bigram[1], bigram[0], X_ik)

# %% [markdown]
# ## 3. Prepare train data

# %%
import math

def random_batch(batch_size, word_sequence, skip_grams, X_ik, weighting_dic):
    
    random_inputs, random_labels, random_coocs, random_weightings = [], [], [], []
    
    #convert our skipgrams to id
    skip_grams_id = [(word2index[skip_gram[0]], word2index[skip_gram[1]]) for skip_gram in skip_grams]
    
    #randomly choose indexes based on batch size
    random_index = np.random.choice(range(len(skip_grams_id)), batch_size, replace=False)
    
    #get the random input and labels
    for index in random_index:
        random_inputs.append([skip_grams_id[index][0]])
        random_labels.append([skip_grams_id[index][1]])
        #coocs
        pair = skip_grams[index] #e.g., ('banana', 'fruit')
        try:
            cooc = X_ik[pair]
        except:
            cooc = 1
        random_coocs.append([math.log(cooc)])
    
        #weightings
        weighting = weighting_dic[pair]
        random_weightings.append([weighting])
        
    return np.array(random_inputs), np.array(random_labels), np.array(random_coocs), np.array(random_weightings)

# %% [markdown]
# ### Testing the method

# %%
batch_size = 2
x, y, cooc, weighting = random_batch(batch_size, corpus, skip_grams, X_ik, weighting_dic)

# %%
print(f"Size of X is : {x}")
print(f"Size of Y is : {y}")
print(f"Size of cooc is : {cooc}")
print(f"Size of weighting is : {weighting}")
# Out:
# Size of X is : [[3487]
#  [3046]]
# Size of Y is : [[3915]
#  [ 641]]
# Size of cooc is : [[0.69314718]
#  [0.69314718]]
# Size of weighting is : [[0.05318296]
#  [0.05318296]]

# %% [markdown]
# ## 4. Model
#
# <img src ="../figures/glove.png" width=400>

# %%
# Define Glove model for training word embeddings from scratch

class Glove(nn.Module):
    
    def __init__(self, voc_size, emb_size):
        super(Glove, self).__init__()
        self.center_embedding  = nn.Embedding(voc_size, emb_size)
        self.outside_embedding = nn.Embedding(voc_size, emb_size)
        
        self.center_bias       = nn.Embedding(voc_size, 1) 
        self.outside_bias      = nn.Embedding(voc_size, 1)
    
    def forward(self, center, outside, coocs, weighting):
        center_embeds  = self.center_embedding(center) #(batch_size, 1, emb_size)
        outside_embeds = self.outside_embedding(outside) #(batch_size, 1, emb_size)
        
        center_bias    = self.center_bias(center).squeeze(1)
        target_bias    = self.outside_bias(outside).squeeze(1)
        
        inner_product  = outside_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        #(batch_size, 1, emb_size) @ (batch_size, emb_size, 1) = (batch_size, 1, 1) = (batch_size, 1)
        
        loss = weighting * torch.pow(inner_product + center_bias + target_bias - coocs, 2)
        
        return torch.sum(loss)

    def get_embed(self, index):
        # Retrieve the embedding for a specific word index.
        with torch.no_grad():  # Ensure gradients are not tracked
            return self.center_embedding(torch.LongTensor([index])).squeeze(0)

# %%
#test our system
voc_size = len(vocabs)
emb_size = 2
model = Glove(voc_size, emb_size)

# %%
# prepare the data
x_tensor = torch.LongTensor(x)
y_tensor = torch.LongTensor(y)
cooc_tensor = torch.FloatTensor(cooc)
weighting_tensor = torch.FloatTensor(weighting)

# %%
# sending model and all the tensors to cuda device
model.to(device)
x_tensor = x_tensor.to(device)
y_tensor = y_tensor.to(device)
cooc_tensor = cooc_tensor.to(device)
weighting_tensor = weighting_tensor.to(device)
loss = model(x_tensor, y_tensor, cooc_tensor, weighting_tensor)

# %%
loss
# Out:
# tensor(0.3846, device='cuda:0', grad_fn=<SumBackward0>)

# %% [markdown]
# ## 5. Training

# %%
batch_size     = 10 # mini-batch size
embedding_size = 2 #so we can later plot
model          = Glove(voc_size, embedding_size).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
import time

# Training
num_epochs = 5000
start = time.time()

for epoch in range(num_epochs):
    
    input_batch, target_batch, cooc_batch, weighting_batch = random_batch(batch_size, corpus, skip_grams, X_ik, weighting_dic)
    input_batch  = torch.LongTensor(input_batch).to(device)         #[batch_size, 1]
    target_batch = torch.LongTensor(target_batch).to(device)        #[batch_size, 1]
    cooc_batch   = torch.FloatTensor(cooc_batch).to(device)         #[batch_size, 1]
    weighting_batch = torch.FloatTensor(weighting_batch).to(device) #[batch_size, 1]

    optimizer.zero_grad()
    loss = model(input_batch, target_batch, cooc_batch, weighting_batch)
    
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 1000 == 0:
        print(f"Epoch: {epoch + 1} | cost: {loss:.6f}")

# Calculate the elapsed time
end = time.time()
epoch_mins, epoch_secs = epoch_time(start, end)
print(f"Training of {num_epochs} epochs were completed in {epoch_mins}m {epoch_secs}s.")
# Out:
# Epoch: 1000 | cost: 23.062525
# Epoch: 2000 | cost: 10.680178
# Epoch: 3000 | cost: 2.802446
# Epoch: 4000 | cost: 17.618662
# Epoch: 5000 | cost: 3.055760
# Training of 5000 epochs were completed in 1m 37s.

# %% [markdown]
# 5. Model Comparism and Analysis

# %%
# function for opening the word anologies text file
def open_file(path_to_file):
    try:
        with open(path_to_file, 'r') as file:
            content = file.readlines()
    except FileNotFoundError:
        print(f"The file {path_to_file} does not exist.")
    except Exception as e:
        print(f"An error occurred: {e}")

    return content

# %%
# 1. Opening the word analogies text file
file_path = "data/word-test.v1.txt"
content = open_file(file_path)

# 2. Parsing the content of the file and create sematic and syntactic analogies 
semantic = []
syntactic = []

current_test = semantic
for sent in content:
    if sent.startswith(':'):
        if 'gram' in sent:
            current_test = syntactic
        else:
            current_test = semantic
        continue
    
    current_test.append(sent.strip().split())

print(f"Number of semantic analogies: {len(semantic)}")
print(f"Number of syntactic analogies: {len(syntactic)}")
# Out:
# Number of semantic analogies: 8869
# Number of syntactic analogies: 10675

# %%
# 1. Function to find the closest word to a given analogy

def find_analogy(word_a, word_b, word_c, model, word2index, index2word):
    try:
        # Get the embeddings for the words
        emb_a = model.get_embed(word2index[word_a])
        emb_b = model.get_embed(word2index[word_b])
        emb_c = model.get_embed(word2index[word_c])
        
        # Perform analogy computation: emb_a - emb_b + emb_c
        analogy_vector = emb_a - emb_b + emb_c

        # Find the closest word to the analogy vector
        all_embeddings = model.center_embedding.weight  # Ensure this tensor is on the same device
        scores = torch.matmul(analogy_vector, all_embeddings.T)
        predicted_index = scores.argmax().item()

        return index2word[predicted_index]
    except KeyError as e:
        return f"Word not in vocabulary: {e}"

# 2. Function to evaluate the model on the analogies

def evaluate_analogies(analogies, model, word2index, index2word):
    correct = 0
    for analogy in analogies:
        word_a, word_b, word_c, word_d = analogy
        predicted_word = find_analogy(word_a, word_b, word_c, model, word2index, index2word)
        if predicted_word == word_d:
            correct += 1
    return correct / len(analogies)

# Evaluate semantic and syntactic analogies
model.to('cpu')
semantic_accuracy = evaluate_analogies(semantic, model, word2index, index2word)
syntactic_accuracy = evaluate_analogies(syntactic, model, word2index, index2word)

print(f"Semantic analogy accuracy: {semantic_accuracy * 100:.2f}%")
print(f"Syntactic analogy accuracy: {syntactic_accuracy * 100:.2f}%")
# Out:
# Semantic analogy accuracy: 0.00%
# Syntactic analogy accuracy: 0.00%

# %%
# 1. Opening the similarities data text file
file_path = "data/wordsim_similarity_goldstandard.txt"
content = open_file(file_path)

similarity_dataset = []
for sent in content:
    word1, word2, similarity = sent.split('\t')
    similarity_dataset.append((word1, word2, float(similarity)))

print(similarity_dataset)
# Out:
# [('tiger', 'cat', 7.35), ('tiger', 'tiger', 10.0), ('plane', 'car', 5.77), ('train', 'car', 6.31), ('television', 'radio', 6.77), ('media', 'radio', 7.42), ('bread', 'butter', 6.19), ('cucumber', 'potato', 5.92), ('doctor', 'nurse', 7.0), ('professor', 'doctor', 6.62), ('student', 'professor', 6.81), ('smart', 'stupid', 5.81), ('wood', 'forest', 7.73), ('money', 'cash', 9.15), ('king', 'queen', 8.58), ('king', 'rook', 5.92), ('bishop', 'rabbi', 6.69), ('fuck', 'sex', 9.44), ('football', 'soccer', 9.03), ('football', 'basketball', 6.81), ('football', 'tennis', 6.63), ('Arafat', 'Jackson', 2.5), ('physics', 'chemistry', 7.35), ('vodka', 'gin', 8.46), ('vodka', 'brandy', 8.13), ('drink', 'eat', 6.87), ('car', 'automobile', 8.94), ('gem', 'jewel', 8.96), ('journey', 'voyage', 9.29), ('boy', 'lad', 8.83), ('coast', 'shore', 9.1), ('asylum', 'madhouse', 8.87), ('magician', 'wizard', 9.02), ('midday', 'noon', 9.29), ('furnace', 'stove', 8.79), ('food', 'fruit', 7.52), ('bird', 'cock', 7.1), ('bird', 'crane', 7.38), ('food', 'rooster', 4.42), ('money', 'dollar', 8.42), ('money', 'currency', 9.04), ('tiger', 'jaguar', 8.0), ('tiger', 'feline', 8.0), ('tiger', 'carnivore', 7.08), ('tiger', 'mammal', 6.85), ('tiger', 'animal', 7.0), ('tiger', 'organism', 4.77), ('tiger', 'fauna', 5.62), ('psychology', 'psychiatry', 8.08), ('psychology', 'science', 6.71), ('psychology', 'discipline', 5.58), ('planet', 'star', 8.45), ('planet', 'moon', 8.08), ('planet', 'sun', 8.02), ('precedent', 'example', 5.85), ('precedent', 'antecedent', 6.04), ('cup', 'tableware', 6.85), ('cup', 'artifact', 2.92), ('cup', 'object', 3.69), ('cup', 'entity', 2.15), ('jaguar', 'cat', 7.42), ('jaguar', 'car', 7.27), ('mile', 'kilometer', 8.66), ('skin', 'eye', 6.22), ('Japanese', 'American', 6.5), ('century', 'year', 7.59), ('announcement', 'news', 7.56), ('doctor', 'personnel', 5.0), ('Harvard', 'Yale', 8.13), ('hospital', 'infrastructure', 4.63), ('life', 'death', 7.88), ('travel', 'activity', 5.0), ('type', 'kind', 8.97), ('street', 'place', 6.44), ('street', 'avenue', 8.88), ('street', 'block', 6.88), ('cell', 'phone', 7.81), ('dividend', 'payment', 7.63), ('calculation', 'computation', 8.44), ('profit', 'loss', 7.63), ('dollar', 'yen', 7.78), ('dollar', 'buck', 9.22), ('phone', 'equipment', 7.13), ('liquid', 'water', 7.89), ('marathon', 'sprint', 7.47), ('seafood', 'food', 8.34), ('seafood', 'lobster', 8.7), ('lobster', 'food', 7.81), ('lobster', 'wine', 5.7), ('championship', 'tournament', 8.36), ('man', 'woman', 8.3), ('man', 'governor', 5.25), ('murder', 'manslaughter', 8.53), ('opera', 'performance', 6.88), ('Mexico', 'Brazil', 7.44), ('glass', 'metal', 5.56), ('aluminum', 'metal', 7.83), ('rock', 'jazz', 7.59), ('museum', 'theater', 7.19), ('shower', 'thunderstorm', 6.31), ('monk', 'oracle', 5.0), ('cup', 'food', 5.0), ('journal', 'association', 4.97), ('street', 'children', 4.94), ('car', 'flight', 4.94), ('space', 'chemistry', 4.88), ('situation', 'conclusion', 4.81), ('word', 'similarity', 4.75), ('peace', 'plan', 4.75), ('consumer', 'energy', 4.75), ('ministry', 'culture', 4.69), ('smart', 'student', 4.62), ('investigation', 'effort', 4.59), ('image', 'surface', 4.56), ('life', 'term', 4.5), ('start', 'match', 4.47), ('computer', 'news', 4.47), ('board', 'recommendation', 4.47), ('lad', 'brother', 4.46), ('observation', 'architecture', 4.38), ('coast', 'hill', 4.38), ('deployment', 'departure', 4.25), ('benchmark', 'index', 4.25), ('attempt', 'peace', 4.25), ('consumer', 'confidence', 4.13), ('start', 'year', 4.06), ('focus', 'life', 4.06), ('development', 'issue', 3.97), ('theater', 'history', 3.91), ('situation', 'isolation', 3.88), ('profit', 'warning', 3.88), ('media', 'trading', 3.88), ('chance', 'credibility', 3.88), ('precedent', 'information', 3.85), ('architecture', 'century', 3.78), ('population', 'development', 3.75), ('stock', 'live', 3.73), ('peace', 'atmosphere', 3.69), ('morality', 'marriage', 3.69), ('minority', 'peace', 3.69), ('atmosphere' ...

# %%
def compute_similarity(model, test_data):
    words = test_data.split("\t")

    embed0 = np.array(model.get_embed(words[0].strip()))
    embed1 = np.array(model.get_embed(words[1].strip()))

    similarity_model = embed1 @ embed0.T
    similarity_provided = float(words[2].strip())

    return similarity_provided, similarity_model

# %%
from scipy.stats import spearmanr

# Compute the dot product for each word pair
dot_products = []
similarity_scores = []

for word1, word2, similarity in similarity_dataset:
    if word1 in word2index and word2 in word2index:
        emb1 = model.get_embed(word2index[word1])
        emb2 = model.get_embed(word2index[word2])
        dot_product = torch.dot(emb1, emb2).item()
        dot_products.append(dot_product)
        similarity_scores.append(similarity)

# Calculate the Spearman correlation
correlation, _ = spearmanr(dot_products, similarity_scores)
print(f"Spearman correlation: {correlation:.4f}")
# Out:
# Spearman correlation: -0.2576

# %% [markdown]
# 7. Save the model

# %%
import pickle

torch.save(model.state_dict(), 'glove.model')

glove_args = {
    'voc_size': voc_size,
    'emb_size': emb_size,
    'word2index': word2index,
}

pickle.dump(glove_args, open('glove.args', 'wb'))

# %%
glove_args = pickle.load(open('glove.args', 'rb'))
print("Loaded Arguments:", glove_args)  # Debug: Check what arguments were saved

glove_args.pop('word2index', None)  # Remove keys not required by the constructor

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
load_model = Glove(**glove_args)

# Load the model weights onto the correct device
load_model.load_state_dict(torch.load('glove.model', map_location=device))
load_model.eval()  # Set the model to evaluation mode
# Out:
# Loaded Arguments: {'voc_size': 4488, 'emb_size': 2, 'word2index': {'strong': 0, 'convene': 1, 'however': 2, 'Ours': 3, 'border': 4, 'AGO': 5, 'pact': 6, 'different': 7, 'German': 8, 'Paton': 9, "'": 10, '900': 11, 'operate': 12, 'Production': 13, 'Drake': 14, 'roasters': 15, 'Commission': 16, 'voluntary': 17, 'THROUGH': 18, 'these': 19, 'states': 20, 'consequences': 21, 'us': 22, 'mouth': 23, 'Sebaana': 24, 'off': 25, 'Lehman': 26, 'Demico': 27, 'backing': 28, 'GUAXUPE': 29, 'Bomani': 30, 'rose': 31, '3198': 32, 'severe': 33, 'cooperative': 34, 'measure': 35, 'may': 36, 'castor': 37, 'arrangement': 38, 'shortfall': 39, 'registering': 40, 'Bureau': 41, 'initiative': 42, 'moment': 43, 'nine': 44, 'French': 45, 'clause': 46, 'level': 47, 'solve': 48, 'background': 49, '255': 50, 'content': 51, 'clarification': 52, 'QUOTA': 53, 'repayments': 54, 'Chartered': 55, 'attracted': 56, 'weather': 57, 'exporters': 58, 'decided': 59, 'pct': 60, 'pack': 61, 'opening': 62, 'VOTUPORANGA': 63, '.': 64, 'Commercial': 65, 'equipment': 66, 'indication': 67, 'Dlrs': 68, 'between': 69, 'salaried': 70, 'generally': 71, 'Paine': 72, 'aware': 73, 'RESETTLE': 74, 'loading': 75, '67': 76, 'position': 77, 'effects': 78, 'identified': 79, 'phase': 80, 'Cadenas': 81, 'speculate': 82, 'aircraft': 83, 'PACT': 84, 'april': 85, 'SITUATION': 86, 'fail': 87, 'exclusive': 88, 'DUTCH': 89, 'MARINGA': 90, 'intervention': 91, 'accords': 92, 'eventual': 93, 'worth': 94, '72': 95, 'products': 96, 'introduce': 97, 'Hock': 98, '276': 99, '25': 100, 'Within': 101, 'tackle': 102, 'handle': 103, 'individual': 104, 'determined': 105, 'Addis': 106, 'GROWTH': 107, 'threatened': 108, 'MILLIMETRES': 109, 'Daniel': 110, 'UGANDA': 111, 'promotion': 112, 'short': 113, 'REVENUE': 114, 'estimate': 115, 'benefit': 116, 'Pressure': 117, 'ETHIOPIA': 118, 'premium': 119, 'mln': 120, 'potential': 121, 'unusually': 122, 'automatically': 123, 'believe': 124, 'teas': 125, '905': 126, 'ADDITIVES': 127, 'by': 128, 'Yoweri': 129, 'hidden': 130, 'limited': 131, 'Development': 132, 'UP': 133, 'touched': 134, 'record': 135, 'power': 136, 'pool': 137, 'rail': 138, 'Korean': 139, 'HITS': 140, 'base': 141, 'sharp': 142, 'overproduction': 143, '45': 144, 'prefer': 145, 'Bros': 146, 'countered': 147, 'commit': 148, 'end': 149, 'territory': 150, 'margin': 151, 'reviewing': 152, 'stabilise': 153, 'also': 154, 'NAMES': 155, 'analyses': 156, 'shares': 157, 'wants': 158, 'causing': 159, '630': 160, 'figure': 161, 'REPORTS': 162, '63': 163, '4': 164, 'PRESSURING': 165, '108': 166, 'PERU': 167, 'dim': 168, 'emphasis': 169, 'says': 170, 'while': 171, 'down': 172, 'Switzerland': 173, 'HB': 174, 'ensuring': 175, 'modest': 176, 'liberalisation': 177, 'EASES': 178, 'Commodities': 179, 'Enapal': 180, 'teeth': 181, 'closest': 182, 'Cesar': 183, 'delay': 184, 'EXPAND': 185, 'No': 186, 'although': 187, 'part': 188, 'work': 189, 'Costa': 190, 'Oripes': 191, 'STC': 192, 'subsidies': 193, 'JACOBS': 194, 'RECORDED': 195, 'implement': 196, 'cotton': 197, 'withheld': 198, 'rid': 199, 'QUALITIES': 200, 'EXECUTIVE': 201, 'receipts': 202, 'reimposition': 203, 'immediately': 204, 'visit': 205, 'Brasilia': 206, 'managers': 207, 'direction': 208, 'HEATS': 209, 'Ugandan': 210, 'loan': 211, 'PARTNER': 212, 'showpiece': 213, 'finished': 214, 'let': 215, 'bottlenecks': 216, 'Saturday': 217, 'adjust': 218, 'expect': 219, 'taken': 220, 'economics': 221, 'Dan': 222, 'Togo': 223, 'Roasters': 224, 'squeeze': 225, 'bureau': 226, 'items': 227, 'break': 228, 'TRADERS': 229, 'Floods': 230, '123': 231, 'tumbled': 232, 'bills': 233, 'virtual': 234, 'shortage': 235, 'salvage': 236, 'union': 237, 'Producing': 238, 'through': 239, '97': 240, 'rates': 241, 'confessed': 242, 'preferable': 243, 'bearing': 244, '976': 245, 'act': 246, 'fifth': 247, '039': 248, 'destinations': 249, 'drilling': 250, 'wish': 251, 'must': 252, 'thing': 253, '000': 254, 'want': 255, 'top': 256, 'infant': 257, '194': 258, 'es': 259, 'cheap': 260, 'major': 261, 'So': 262, ' ...
# C:\Users\mgmgk\AppData\Local\Temp\ipykernel_26404\3779503479.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   load_model.load_state_dict(torch.load('glove.model', map_location=device))
# Glove(
#   (center_embedding): Embedding(4488, 2)
#   (outside_embedding): Embedding(4488, 2)
#   (center_bias): Embedding(4488, 1)
#   (outside_bias): Embedding(4488, 1)
# )

# %%
sample_input = torch.tensor([[1], [2]])  # Replace with appropriate test data
print("Sample Output:", load_model(sample_input, sample_input, cooc_tensor, weighting_tensor))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[33], line 2
#       1 sample_input = torch.tensor([[1], [2]])  # Replace with appropriate test data
# ----> 2 print("Sample Output:", load_model(sample_input, sample_input, cooc_tensor, weighting_tensor))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[17], line 23, in Glove.forward(self, center, outside, coocs, weighting)
#      20 inner_product  = outside_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
#      21 #(batch_size, 1, emb_size) @ (batch_size, emb_size, 1) = (batch_size, 1, 1) = (batch_size, 1)
# ---> 23 loss = weighting * torch.pow(inner_product + center_bias + target_bias - coocs, 2)
#      25 return torch.sum(loss)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu!

# %%
words = ('import', 'export', 'soccer', 'king', 'rice','war', 'crop' )  # Replace with the word analogy to find

# Convert word to index
for word in words:
    if word in word2index:
        word_index = word2index[word]
        embedding = load_model.get_embed(word_index)  # Pass the index
        print(f"Embedding for '{word}': {embedding}")
    else:
        print(f"Word '{word}' not found in vocabulary.")
# Out:
# Embedding for 'import': tensor([1.1444, 0.6871])
# Embedding for 'export': tensor([ 0.9110, -0.2708])
# Word 'soccer' not found in vocabulary.
# Word 'king' not found in vocabulary.
# Embedding for 'rice': tensor([0.1855, 0.9371])
# Embedding for 'war': tensor([0.1801, 0.3997])
# Embedding for 'crop': tensor([0.2758, 0.6148])

# %%
def get_top_similar_contexts(query, model, corpus, word2index, top_n=10):
    # Convert the query to its embedding
    query_embedding = model.get_embed(word2index[query])
    
    # Flatten the corpus to get all words
    flattened_corpus = [word for sentence in corpus for word in sentence]
    
    # Compute the dot product between the query embedding and each word in the corpus
    similarities = []
    for word in flattened_corpus:
        if word in word2index:
            word_embedding = model.get_embed(word2index[word])
            dot_product = torch.dot(query_embedding, word_embedding).item()
            similarities.append((word, dot_product))
    
    # Sort the similarities in descending order and get the top N
    similarities.sort(key=lambda x: x[1], reverse=True)
    top_similar_contexts = similarities[:top_n]
    
    return top_similar_contexts

# Example usage
query = 'robusta'  # Replace with your query word
if query in word2index:
    top_similar_contexts = get_top_similar_contexts(query, model, corpus, word2index)
    print(top_similar_contexts)
    #word_index = word2index[word]
    #embedding = load_model.get_embed(word_index)  # Pass the index
    #print(f"Embedding for '{word}': {embedding}")
else:
    print(f"Word '{query}' not found in vocabulary.")
# Out:
# [('supported', 3.2373929023742676), ('supported', 3.2373929023742676), ('route', 3.2316250801086426), ('route', 3.2316250801086426), ('route', 3.2316250801086426), ('FAILURE', 3.2306151390075684), ('FAILURE', 3.2306151390075684), ('FAILURE', 3.2306151390075684), ('FAILURE', 3.2306151390075684), ('FAILURE', 3.2306151390075684)]
